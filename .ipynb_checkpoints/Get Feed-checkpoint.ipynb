# %%
# !pip install selenium 
# !pip install beautifulsoup4
#
#!pip install webdriver-manager
#!pip install lxml
#!pip install spacy
#!python3 -m spacy download en_core_web_lg
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 3.1 MB/s eta 0:00:00m eta 0:00:010:00:03
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /home/rohit/.local/lib/python3.10/site-packages (from en-core-web-lg==3.7.1) (3.7.5)
# Requirement already satisfied: numpy>=1.19.0 in /home/rohit/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.26.4)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/rohit/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.9)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /home/rohit/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/rohit/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.32.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/rohit/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/rohit/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.66.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/rohit/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/rohit/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.1.3)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /home/rohit/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.4.1)
# Requirement already satisfied: packaging>=20.0 in /home/rohit/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (24.1)
# Requirement already satisfied: jinja2 in /home/rohit/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.1.4)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/rohit/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.5)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /home/rohit/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/rohit/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/rohit/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/rohit/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.4.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /home/rohit/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.8.2)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (59.6.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/rohit/.local/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: language-data>=1.2 in /home/rohit/.local/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.2.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/rohit/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/rohit/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/rohit/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/rohit/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.26.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/rohit/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2024.7.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/rohit/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/rohit/.local/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.5)
# Requirement already satisfied: rich>=10.11.0 in /home/rohit/.local/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (13.7.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/rohit/.local/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.5.4)
# Requirement already satisfied: click>=8.0.0 in /usr/lib/python3/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.0.3)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /home/rohit/.local/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /home/rohit/.local/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/lib/python3/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in /home/rohit/.local/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/rohit/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/rohit/.local/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.0)
# Requirement already satisfied: wrapt in /home/rohit/.local/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /home/rohit/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time
import spacy
nlp = spacy.load('en_core_web_lg')

# Creating a webdriver instance
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
# This instance will be used to log into LinkedIn

# Opening linkedIn's login page
driver.get("https://linkedin.com/uas/login")

# waiting for the page to load
time.sleep(5)

# entering username
username = driver.find_element(By.ID, "username")

# In case of an error, try changing the element
# tag used here.

# Enter Your Email Address
username.send_keys("rohit108180@gmail.com") 

# entering password
pword = driver.find_element(By.ID, "password")
# In case of an error, try changing the element 
# tag used here.

# Enter Your Password
pword.send_keys("Rt9312040284")	 

# Clicking on the log in button
# Format (syntax) of writing XPath --> 
# //tagname[@attribute='value']
driver.find_element(By.XPATH, "//button[@type='submit']").click()
# In case of an error, try changing the
# XPath used here.

profile_url = "https://www.linkedin.com/feed"
 
driver.get(profile_url)

# %%
start = time.time()

# will be used in the while loop
initialScroll = 0
finalScroll = 1000

while True:
	driver.execute_script(f"window.scrollTo({initialScroll},{finalScroll})")
	# this command scrolls the window starting from
	# the pixel value stored in the initialScroll 
	# variable to the pixel value stored at the
	# finalScroll variable
	initialScroll = finalScroll
	finalScroll += 1000

	# we will stop the script for 3 seconds so that 
	# the data can load
	time.sleep(3)
	# You can change it as per your needs and internet speed

	end = time.time()

	# We will scroll for 20 seconds.
	# You can change it as per your needs and internet speed
	if round(end - start) > 40:
		break

# %%
src = driver.page_source
 
# Now using beautiful soup
soup = BeautifulSoup(src, 'lxml')
# f = open("feed.txt", "w")
# f.write(src)
# f.close()

# %%
# Extracting the HTML of the complete introduction box
# that contains the name, company name, and the location
feeds = soup.find_all('div', {'class': 'feed-shared-update-v2__description-wrapper'})
 
print(feeds)
# Out:
# [<div class="feed-shared-update-v2__description-wrapper mr2" style="" tabindex="-1">
# <div class="feed-shared-inline-show-more-text feed-shared-update-v2__description feed-shared-inline-show-more-text--minimal-padding feed-shared-inline-show-more-text--2-lines" tabindex="-1">
# <div class="update-components-text relative update-components-update-v2__commentary" dir="ltr">
# <!-- -->
# <span class="break-words tvm-parent-container">
# <!-- --> <span dir="ltr"><!-- -->Watch the video till the end ! I'm still looking for these recruiters from<span class="white-space-pre"> </span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=amazon&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7229719013558300672"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>amazon</span></a><!-- -->,<span class="white-space-pre"> </span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=google&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7229719013558300672"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>google</span></a><span class="white-space-pre"> </span><!-- --><!-- --><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=ey&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7229719013558300672"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>ey</span></a><span class="white-space-pre"> </span>who will run after me !<!-- --><span><br/></span><span><br/></span><!-- -->What are your thoughts about these constant disturbing ads on<span class="white-space-pre"> </span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/company/youtube/" target="_self"><span><span><!-- -->YouTube<!-- --></span></span></a><span><br/></span><span><br/></span><!-- -->Follow me and I will help you to find your dream job:<span class="white-space-pre"> </span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/in/ACoAABUwy1QBpAq94qljJiK8_wMMpdeo7EckLbo" target="_self"><span><a class="ember-view" href="/in/careerwithvasanth/" id="ember48"><!-- -->Vasanth Bhat<!-- --></a></span></a></span>
# </span>
# </div>
# <button aria-label="see more, visually reveals content which is already detected by screen readers" class="feed-shared-inline-show-more-text__see-more-less-toggle see-more t-14 t-black--light t-normal hoverable-link-text feed-shared-inline-show-more-text__dynamic-more-text" role="button" style="left:230.15000915527344px" type="button">
# <span>…more</span>
# </button><!-- --> </div>
# <!-- --> </div>, <div class="feed-shared-update-v2__description-wrapper mr2" style="" tabindex="-1">
# <div class="feed-shared-inline-show-more-text feed-shared-update-v2__description feed-shared-inline-show-more-text--minimal-padding feed-shared-inline-show-more-text--2-lines" tabindex="-1">
# <div class="update-components-text relative update-components-update-v2__commentary" dir="ltr">
# <!-- -->
# <span class="break-words tvm-parent-container">
# <!-- --> <span dir="ltr"><!-- -->Set up job alerts, and be the first to hear when new job openings are posted.<span class="white-space-pre"> </span><a attributionsrc="https://px.ads.linkedin.com/attribution_source?campaign_id=167186963&amp;creative_id=460211846&amp;impression_id=8f04e54d-24ff-417f-936b-d904e09bcbe4&amp;destination=https%3A%2F%2Flnkd.in%2FgCPAWmGe&amp;member_id=884865109" class="app-aware-link" data-test-app-aware-link="" href="https://lnkd.in/gCPAWmGe" target="_self"><!-- -->https://lnkd.in/gCPAWmGe<!-- --></a></span>
# </span>
# </div>
# <!-- --><!-- --> </div>
# <!-- --> </div>, <div class="feed-shared-update-v2__description-wrapper mr2" style="" tabindex="-1">
# <div class="feed-shared-inline-show-more-text feed-shared-update-v2__description feed-shared-inline-show-more-text--minimal-padding feed-shared-inline-show-more-text--2-lines" tabindex="-1">
# <div class="update-components-text relative update-components-update-v2__commentary" dir="ltr">
# <!-- -->
# <span class="break-words tvm-parent-container">
# <!-- --> <span dir="ltr"><!-- -->If you're aiming to prepare for 𝐃𝐒𝐀 in the most organised way possible, I will recommend you these two resources:<!-- --><span><br/></span><span><br/></span><!-- -->𝐒𝐭𝐫𝐢𝐯𝐞𝐫'𝐬 𝐀2𝐙 𝐃𝐒𝐀 𝐒𝐡𝐞𝐞𝐭: This sheet includes 455 modules that cover everything from start to finish in a highly structured manner. Each problem is has video solutions, making it easier to understand the concepts. Currently, over 600,000 users use this sheet every month.<!-- --><span><br/></span><span><br/></span><!-- -->𝐓𝐔𝐅+: Ideal for both beginners and those looking to get serious about their preparation, it offers a curated set of 100+ problems to get you started. After that, you'll have access to 300+ curated problems to keep your preparation on track.<span class="white-space-pre"> </span><span><br/></span><span><br/></span><!-- -->- Personalised roadmap (When you enter your number of days)<!-- --><span><br/></span><!-- -->- Topic-wise contests<!-- --><span><br/></span><!-- -->- Descriptive Editorials in all 4 languages (C++, Java, Python and Js)<!-- --><span><br/></span><!-- -->- A practice portal with all premium problems<!-- --><span><br/></span><!-- -->- AI-powered Doubt Solver (works exceptionally well when you describe your doubt thoroughly, thanks to our specialized dataset)<!-- --><span><br/></span><!-- -->- AI-powered Code Reviewer (gives feedback like a senior engineer would)<!-- --><span><br/></span><!-- -->- AI Complexity Analyzer<!-- --><span><br/></span><!-- -->- Weekly sessions with me<!-- --><span><br/></span><!-- -->- Section-wise(Brute/Better) video solutions for easier understanding and saving your time<!-- --><span><br/></span><!-- -->- Core subjects like OOPS and many more features coming in October under TUF+<!-- --><span><br/></span><span><br/></span><!-- -->A2Z is an amazing option if you have time, and you can switch multiple tabs, do a bit of google search.<span class="white-space-pre"> </span><span><br/></span><span><br/></span><!-- -->But if you're looking to save time and make your process easier with one click, TUF+ is the way to go.<span class="white-space-pre"> </span><span><br/></span><span><br/></span><!-- -->To celebrate Independence Day, we're offering 𝐓𝐔𝐅+ at its lowest price ever.<!-- --><span><br/></span><span><br/></span><!-- -->Check it out:<span class="white-space-pre"> </span><a class="app-aware-link" data-test-app-aware-link="" href="https://lnkd.in/d4CV7_A5" target="_self"><!-- -->https://lnkd.in/d4CV7_A5<!-- --></a></span>
# </span>
# </div>
# <button aria-label="see more, visually reveals content which is already detected by screen readers" class="feed-shared-inline-show-more-text__see-more-less-toggle see-more t-14 t-black--light t-normal hoverable-link-text feed-shared-inline-show-more-text__dynamic-more-text" role="button" style="left:237.53749084472656px" type="button">
# <span>…more</span>
# </button><!-- --> </div>
# <!-- --> </div>, <div class="feed-shared-update-v2__description-wrapper mr2" style="" tabindex="-1">
# <div class="feed-shared-inline-show-more-text feed-shared-update-v2__description feed-shared-inline-show-more-text--minimal-padding feed-shared-inline-show-more-text--3-lines" tabindex="-1">
# <div class="update-components-text relative update-components-update-v2__commentary" dir="ltr">
# <!-- -->
# <span class="break-words tvm-parent-container">
# <!-- --> <span dir="ltr"><!-- -->Happy Independence day everyone 🇮🇳<span class="white-space-pre"> </span><span><br/></span><span><br/></span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/company/servicenow/" target="_self"><span><span><!-- -->ServiceNow<!-- --></span></span></a><span class="white-space-pre"> </span>is hiring Software Engineer freshers<!-- --><span><br/></span><span><br/></span><!-- -->Requirements :<!-- --><span><br/></span><!-- -->-&gt; 0-2 years of experience with Java or a similar OO language<!-- --><span><br/></span><!-- -->-&gt; Passion for JavaScript and the Web as a platform, reusability, and componentization<!-- --><span><br/></span><!-- -->-&gt; Experience with data structures, algorithms, object-oriented design, design patterns, and performance/scale considerations<!-- --><span><br/></span><!-- -->-&gt; Experience with any of the modern UI frameworks like Angular, React or Vue<!-- --><span><br/></span><!-- -->-&gt; Analytical and design skills<!-- --><span><br/></span><!-- -->-&gt; Working knowledge and ability to use tools to assist with daily tasks (IDE, debugger, build tools, source control, ServiceNow instances, profilers, system administration/Unix tools)<!-- --><span><br/></span><span><br/></span><!-- -->Apply:<!-- --><span><br/></span><a class="app-aware-link" data-test-app-aware-link="" href="https://lnkd.in/g2hTAwAR" target="_self"><!-- -->https://lnkd.in/g2hTAwAR<!-- --></a><span><br/></span><span><br/></span><!-- -->Try referrals from real<span class="white-space-pre"> </span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=servicenow&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7229702018246795264"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>servicenow</span></a><span class="white-space-pre"> </span>employees:<!-- --><span><br/></span><a class="app-aware-link" data-test-app-aware-link="" href="https://lnkd.in/ghErYzvJ" target="_self"><!-- -->https://lnkd.in/ghErYzvJ<!-- --></a><span><br/></span><span><br/></span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=servicenow&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7229702018246795264"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>servicenow</span></a><span class="white-space-pre"> </span><!-- --><!-- --><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=hiring&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7229702018246795264"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>hiring</span></a><span class="white-space-pre"> </span><!-- --><!-- --><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=softwareengineer&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7229702018246795264"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>softwareengineer</span></a><span class="white-space-pre"> </span><!-- --><!-- --><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=freshers&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7229702018246795264"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>freshers</span></a><span class="white-space-pre"> </span><!-- --><!-- --><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=entrylevel&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7229702018246795264"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>entrylevel</span></a><span class="white-space-pre"> </span><!-- --><!-- --><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=sde&amp;highlightedUpdateUrns=urn%3Al ...
# </span>
# </div>
# <button aria-label="see more, visually reveals content which is already detected by screen readers" class="feed-shared-inline-show-more-text__see-more-less-toggle see-more t-14 t-black--light t-normal hoverable-link-text feed-shared-inline-show-more-text__dynamic-more-text" role="button" style="left:308.97499084472656px" type="button">
# <span>…more</span>
# </button><!-- --> </div>
# <!-- --> </div>, <div class="feed-shared-update-v2__description-wrapper mr2" style="" tabindex="-1">
# <div class="feed-shared-inline-show-more-text feed-shared-update-v2__description feed-shared-inline-show-more-text--minimal-padding feed-shared-inline-show-more-text--2-lines" tabindex="-1">
# <div class="update-components-text relative update-components-update-v2__commentary" dir="ltr">
# <!-- -->
# <span class="break-words tvm-parent-container">
# <!-- --> <span dir="ltr"><!-- -->Featuring all-day battery life for marathon study sessions.<!-- --><span><br/></span><!-- -->This back-to-school season, buy MacBook and get ₹10000* instant cashback on credit cards of ICICI Bank and SBI Card. Visit your nearest Apple Authorised Store today. To know more, click:<span class="white-space-pre"> </span><a attributionsrc="https://px.ads.linkedin.com/attribution_source?campaign_id=319731084&amp;creative_id=448876574&amp;impression_id=8c6fd83b-1cdc-4ec7-892b-365b84dab3a0&amp;destination=https%3A%2F%2Flnkd.in%2FgXwkNGGb&amp;member_id=884865109" class="app-aware-link" data-test-app-aware-link="" href="https://lnkd.in/gXwkNGGb" target="_self"><!-- -->https://lnkd.in/gXwkNGGb<!-- --></a><span><br/></span><!-- -->*T&amp;C Apply.<!-- --></span>
# </span>
# </div>
# <button aria-label="see more, visually reveals content which is already detected by screen readers" class="feed-shared-inline-show-more-text__see-more-less-toggle see-more t-14 t-black--light t-normal hoverable-link-text feed-shared-inline-show-more-text__dynamic-more-text" role="button" style="left:477.4750213623047px" type="button">
# <span>…more</span>
# </button><!-- --> </div>
# <!-- --> </div>, <div class="feed-shared-update-v2__description-wrapper mr2" style="" tabindex="-1">
# <div class="feed-shared-inline-show-more-text feed-shared-update-v2__description feed-shared-inline-show-more-text--minimal-padding feed-shared-inline-show-more-text--3-lines" tabindex="-1">
# <div class="update-components-text relative update-components-update-v2__commentary" dir="ltr">
# <!-- -->
# <span class="break-words tvm-parent-container">
# <!-- --> <span dir="ltr"><!-- -->I'm excited to share that I've joined<span class="white-space-pre"> </span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/company/bajaj-auto-ltd/" target="_self"><span><span><!-- -->Bajaj Auto Ltd<!-- --></span></span></a><span class="white-space-pre"> </span>as a Graduate Trainee Engineer. Looking forward to learning and growing with a great team.<span class="white-space-pre"> </span><span><br/></span><!-- -->Thank you to everyone who has supported me on this journey!<!-- --></span>
# </span>
# </div>
# <!-- --><!-- --> </div>
# <!-- --> </div>, <div class="feed-shared-update-v2__description-wrapper mr2" style="" tabindex="-1">
# <div class="feed-shared-inline-show-more-text feed-shared-update-v2__description feed-shared-inline-show-more-text--minimal-padding feed-shared-inline-show-more-text--2-lines" tabindex="-1">
# <div class="update-components-text relative update-components-update-v2__commentary" dir="ltr">
# <!-- -->
# <span class="break-words tvm-parent-container">
# <!-- --> <span dir="ltr"><!-- -->You wake up , you are happy that you don’t need to go to office today , and suddenly<span class="white-space-pre"> </span><span><br/></span><span><br/></span><span><br/></span><!-- -->You hear a low sound of<!-- --><span><br/></span><!-- -->National Anthem &amp;<!-- --><span><br/></span><!-- -->See School kids going to school.<!-- --><span><br/></span><span><br/></span><!-- -->And now we all miss that.<!-- --><span><br/></span><span><br/></span><!-- -->🇮🇳Happy Independence Day 🇮🇳<!-- --><span><br/></span><span><br/></span><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=independenceday&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7229723629716987904"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>independenceday</span></a><span class="white-space-pre"> </span><!-- --><!-- --><a class="app-aware-link" data-test-app-aware-link="" href="https://www.linkedin.com/feed/hashtag/?keywords=india&amp;highlightedUpdateUrns=urn%3Ali%3Aactivity%3A7229723629716987904"><span class="visually-hidden">hashtag</span><span><span aria-hidden="true">#</span>india</span></a></span>
# </span>
# </div>
# <button aria-label="see more, visually reveals content which is already detected by screen readers" class="feed-shared-inline-show-more-text__see-more-less-toggle see-more t-14 t-black--light t-normal hoverable-link-text feed-shared-inline-show-more-text__dynamic-more-text" role="button" style="left:57.42500305175781px" type="button">
# <span>…more</span>
# </button><!-- --> </div>
# <!-- --> </div>, <div class="feed-shared-update-v2__description-wrapper mr2" style="" tabindex="-1">
# <div class="feed-shared-inline-show-more-text feed-shared-update-v2__description feed-shared-inline-show-more-text--minimal-padding feed-shared-inline-show-more-text--2-lines" tabindex="-1">
# <div class="update-components-text relative update-components-update-v2__commentary" dir="ltr">
# <!-- -->
# <span class="break-words tvm-parent-container">
# <!-- --> <span dir="ltr"><!-- -->Invest in the platform built for B2B. Discover ad formats designed to reach your B2B goals.<span class="white-space-pre"> </span><a attributionsrc="https://px.ads.linkedin.com/attribution_source?campaign_id=217270704&amp;creative_id=219087614&amp;impression_id=2158f4bd-5056-47d9-83ef-428083136d8b&amp;destination=https%3A%2F%2Flnkd.in%2FeZZqs699&amp;member_id=884865109" class="app-aware-link" data-test-app-aware-link="" href="https://lnkd.in/eZZqs699" target="_self"><!-- -->https://lnkd.in/eZZqs699<!-- --></a></span>
# </span>
# </div>
# <!-- --><!-- --> </div>
# <!-- --> </div>]

# %%
feed_texts = [ feed.find('span', {'class': 'break-words tvm-parent-container'}) for feed in feeds]
for feed_text in feed_texts:
    print(feed_text.get_text())
    print("\n")
# Out:
#  Watch the video till the end ! I'm still looking for these recruiters from hashtag#amazon, hashtag#google hashtag#ey who will run after me !What are your thoughts about these constant disturbing ads on YouTubeFollow me and I will help you to find your dream job: Vasanth Bhat
#
#
#
#
#  Set up job alerts, and be the first to hear when new job openings are posted. https://lnkd.in/gCPAWmGe
#
#
#
#
#  If you're aiming to prepare for 𝐃𝐒𝐀 in the most organised way possible, I will recommend you these two resources:𝐒𝐭𝐫𝐢𝐯𝐞𝐫'𝐬 𝐀2𝐙 𝐃𝐒𝐀 𝐒𝐡𝐞𝐞𝐭: This sheet includes 455 modules that cover everything from start to finish in a highly structured manner. Each problem is has video solutions, making it easier to understand the concepts. Currently, over 600,000 users use this sheet every month.𝐓𝐔𝐅+: Ideal for both beginners and those looking to get serious about their preparation, it offers a curated set of 100+ problems to get you started. After that, you'll have access to 300+ curated problems to keep your preparation on track. - Personalised roadmap (When you enter your number of days)- Topic-wise contests- Descriptive Editorials in all 4 languages (C++, Java, Python and Js)- A practice portal with all premium problems- AI-powered Doubt Solver (works exceptionally well when you describe your doubt thoroughly, thanks to our specialized dataset)- AI-powered Code Reviewer (gives feedback like a senior engineer would)- AI Complexity Analyzer- Weekly sessions with me- Section-wise(Brute/Better) video solutions for easier understanding and saving your time- Core subjects like OOPS and many more features coming in October under TUF+A2Z is an amazing option if you have time, and you can switch multiple tabs, do a bit of google search. But if you're looking to save time and make your process easier with one click, TUF+ is the way to go. To celebrate Independence Day, we're offering 𝐓𝐔𝐅+ at its lowest price ever.Check it out: https://lnkd.in/d4CV7_A5
#
#
#
#
#  Happy Independence day everyone 🇮🇳 ServiceNow is hiring Software Engineer freshersRequirements :-> 0-2 years of experience with Java or a similar OO language-> Passion for JavaScript and the Web as a platform, reusability, and componentization-> Experience with data structures, algorithms, object-oriented design, design patterns, and performance/scale considerations-> Experience with any of the modern UI frameworks like Angular, React or Vue-> Analytical and design skills-> Working knowledge and ability to use tools to assist with daily tasks (IDE, debugger, build tools, source control, ServiceNow instances, profilers, system administration/Unix tools)Apply:https://lnkd.in/g2hTAwARTry referrals from real hashtag#servicenow employees:https://lnkd.in/ghErYzvJhashtag#servicenow hashtag#hiring hashtag#softwareengineer hashtag#freshers hashtag#entrylevel hashtag#sde hashtag#jobs hashtag#openings hashtag#referrals
#
#
#
#
#  Featuring all-day battery life for marathon study sessions.This back-to-school season, buy MacBook and get ₹10000* instant cashback on credit cards of ICICI Bank and SBI Card. Visit your nearest Apple Authorised Store today. To know more, click: https://lnkd.in/gXwkNGGb*T&C Apply.
#
#
#
#
#  I'm excited to share that I've joined Bajaj Auto Ltd as a Graduate Trainee Engineer. Looking forward to learning and growing with a great team. Thank you to everyone who has supported me on this journey!
#
#
#
#
#  You wake up , you are happy that you don’t need to go to office today , and suddenly You hear a low sound ofNational Anthem &See School kids going to school.And now we all miss that.🇮🇳Happy Independence Day 🇮🇳hashtag#independenceday hashtag#india
#
#
#
#
#  Invest in the platform built for B2B. Discover ad formats designed to reach your B2B goals. https://lnkd.in/eZZqs699

# %%
# Load SpaCy model


# Given text
given_text = nlp("🚀 We're Hiring! Join Our Dynamic Team! We're excited to announce that [Company Name] is expanding, and we're looking for passionate individuals to join us. If you're someone who thrives in a fast-paced environment and loves solving challenging problems, we want to hear from you! Open Positions:Software EngineerLocation: [City, Country]Apply HereData ScientistLocation: [City, Country]Apply HereProduct ManagerLocation: [City, Country]Apply HereWhy [Company Name]?Competitive salary and benefitsOpportunity to work with a talented teamFlexible working hours and remote work optionsProfessional development and growth opportunitiesInterested?Click on the links above to apply or visit our Careers Page. Share this post with anyone who might be a great fit! Let's build something amazing together.#Hiring #JobOpportunity #JoinOurTeam #TechJobs")
# Filter texts based on similarity
threshold = 0.8  # Set your threshold
filtered_texts = [text.get_text() for text in feed_texts if given_text.similarity(nlp(text.get_text())) > threshold]


for feed_text in filtered_texts:
    print(feed_text)
    print("\n")
# Out:
#  If you're aiming to prepare for 𝐃𝐒𝐀 in the most organised way possible, I will recommend you these two resources:𝐒𝐭𝐫𝐢𝐯𝐞𝐫'𝐬 𝐀2𝐙 𝐃𝐒𝐀 𝐒𝐡𝐞𝐞𝐭: This sheet includes 455 modules that cover everything from start to finish in a highly structured manner. Each problem is has video solutions, making it easier to understand the concepts. Currently, over 600,000 users use this sheet every month.𝐓𝐔𝐅+: Ideal for both beginners and those looking to get serious about their preparation, it offers a curated set of 100+ problems to get you started. After that, you'll have access to 300+ curated problems to keep your preparation on track. - Personalised roadmap (When you enter your number of days)- Topic-wise contests- Descriptive Editorials in all 4 languages (C++, Java, Python and Js)- A practice portal with all premium problems- AI-powered Doubt Solver (works exceptionally well when you describe your doubt thoroughly, thanks to our specialized dataset)- AI-powered Code Reviewer (gives feedback like a senior engineer would)- AI Complexity Analyzer- Weekly sessions with me- Section-wise(Brute/Better) video solutions for easier understanding and saving your time- Core subjects like OOPS and many more features coming in October under TUF+A2Z is an amazing option if you have time, and you can switch multiple tabs, do a bit of google search. But if you're looking to save time and make your process easier with one click, TUF+ is the way to go. To celebrate Independence Day, we're offering 𝐓𝐔𝐅+ at its lowest price ever.Check it out: https://lnkd.in/d4CV7_A5
