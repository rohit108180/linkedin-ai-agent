# %%
# !pip install selenium 
# !pip install beautifulsoup4
#
#!pip install webdriver-manager
#!pip install lxml
#!pip install spacy
#!python3 -m spacy download en_core_web_lg
#!python3 -m pip install "pymongo[srv]"

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from datetime import datetime
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import time
import spacy
nlp = spacy.load('en_core_web_lg')
import os
from dotenv import load_dotenv
# Load environment variables from .env file
load_dotenv()

# Access the MongoDB URI
passwordL = os.getenv('LINKEDIN_PASSWORD')


# Creating a webdriver instance
driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
# This instance will be used to log into LinkedIn

# Opening linkedIn's login page
driver.get("https://linkedin.com/uas/login")

# waiting for the page to load
time.sleep(5)

# entering username
username = driver.find_element(By.ID, "username")

# In case of an error, try changing the element
# tag used here.

# Enter Your Email Address
username.send_keys("rohit108180@gmail.com") 

# entering password
pword = driver.find_element(By.ID, "password")
# In case of an error, try changing the element 
# tag used here.

# Enter Your Password
pword.send_keys(passwordL)	 

# Clicking on the log in button
# Format (syntax) of writing XPath --> 
# //tagname[@attribute='value']
driver.find_element(By.XPATH, "//button[@type='submit']").click()
# In case of an error, try changing the
# XPath used here.

# profile_url = "https://www.linkedin.com/feed"
 
# driver.get(profile_url)

# %%
mongo_uri = os.getenv('MONGO_URI')
# SETUP THE MONGO_CONNECTION
uri = mongo_uri if mongo_uri else "mongodb://localhost:27017"


# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
start = time.time()

# will be used in the while loop
initialScroll = 0
finalScroll = 1000

while True:
	driver.execute_script(f"window.scrollTo({initialScroll},{finalScroll})")
	# this command scrolls the window starting from
	# the pixel value stored in the initialScroll 
	# variable to the pixel value stored at the
	# finalScroll variable
	initialScroll = finalScroll
	finalScroll += 1000

	# we will stop the script for 3 seconds so that 
	# the data can load
	time.sleep(3)
	# You can change it as per your needs and internet speed

	end = time.time()

	# We will scroll for 20 seconds.
	# You can change it as per your needs and internet speed
	if round(end - start) > 600:
		break

# %%
src = driver.page_source
 
# Now using beautiful soup
soup = BeautifulSoup(src, 'lxml')
# f = open("feed.txt", "w")
# f.write(src)
# f.close()

# %%
# fie-impression-container
feeds = soup.find_all('div', {'id': 'fie-impression-container'})

# %%
print(len(feeds))
# Out:
# 230

# %%
posts = [];
# getting the names and info about of POSTER
for feed in feeds:
    poster = feed.find('span', {'class': 'update-components-actor__name'})
    if poster :
        poster = poster.find('span', {'class': 'visually-hidden'}).get_text()
        
    
    poster_bio = feed.find('span', {'class': 'update-components-actor__description'})
    if poster_bio :
        poster_bio = poster_bio.find('span', {'class': 'visually-hidden'}).get_text()
    if poster == "LinkedIn for Marketing" or poster == "poster Indian Startup News" or poster_bio == "Promoted" or not poster or not poster_bio:
        continue
    profile = feed.find('a', {'class': 'update-components-actor__sub-description-link'})
    profile = profile["href"] if profile else profile;
    feed_text = feed.find('span', {'class': 'break-words tvm-parent-container'});

    hrefs = feed_text.find_all("a") if feed_text else []
    href_map = {}
    for href in hrefs:
        link_text = href.get_text() if href else ""
        if link_text.find("hashtag#") != -1 or link_text == "" :
            continue;
        href_map[href.get_text()] = href["href"] if href else href;
    post = {}
    post["poster"] = poster;
    post["poster_bio"] =  poster_bio;
    post["profile"] =  profile;
    post["feed_text"] =  feed_text.get_text() if feed_text else feed_text
    post["href_map"] = href_map;
    post["createdAt"] = datetime.utcnow()
    post["status"] = "pending"
    posts.append(post)
    print(post)
    print("\n")
# Out:
# {'poster': 'Vimal Tiwari', 'poster_bio': 'Engineer @Google | Humorist | Not from IIT, NIT, IIIT or IIM', 'profile': 'https://www.linkedin.com/in/vimaltiwari2612?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAABlnG2YBkUKXI21skkqBT3Mrb6HBApJtmgE', 'feed_text': '\n Unknown fact :Every New hire remains happy until they meet,that one colleague in their own team, who makes them realise,"Ki bhai, tu galat jagah aa gaya hai...!!!"hashtag#linkedin hashtag#linkedinglobal hashtag#life hashtag#experience hashtag#success\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 181149), 'status': 'pending'}
#
#
# {'poster': 'Nate D.', 'poster_bio': 'I make stuff in C++', 'profile': 'https://www.linkedin.com/in/nathanieldoromal?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAACrlKcBeaXmV_oromNLGqMqpRUl8XQp6BM', 'feed_text': '\n On the heels of the arrest of Telegram founder Pavel Durov, Mark Zuckerberg just released evidence that the Biden/Harris admin engaged in secret attempts to censor and manipulate public dialogue via inappropriate government pressure on Facebook.I would understand if Biden or Harris had done what John F. Kennedy did during the ill-fated Bay of Pigs invasion of Cuba and accepted full responsibility for the mistake. But they didn\'t do that.Instead, Biden and Harris chose to "sweep it under the rug" and not discuss it. It remains in doubt if they even see what they did as a problem or if they are thinking, "We are doing what\'s necessary for the public good – human rights be damned!"This is the wrong leadership philosophy. Kamala Harris has to take accountability for all her actions and failures. She has to understand and integrate the views of all the people she represents instead of pretending they don\'t exist behind vacuous smiles and laughter.Until she can do this, she is the wrong person to lead the country.\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 183729), 'status': 'pending'}
#
#
# {'poster': 'Indian Startup News', 'poster_bio': '367,911 followers', 'profile': 'https://www.linkedin.com/company/indianstartupnews/posts', 'feed_text': '\n Shark Tank India judge Anupam Mittal, in a recent interaction with NDTV Profit, highlighted a significant shift in the startup ecosystem, referring to it as the "great Indian tech ghar wapsi." He explained that this trend reflects the growing confidence and opportunities within India\'s domestic markets, leading many startups to shift their base back to the country. "Look, sooner or later, Ghar Wapsi was inevitable. Think of it as the great Indian tech ghar wapsi," Mittal said. He noted that for years, the Indian startup community was encouraged to set up bases abroad due to concerns about regulatory hurdles and the reluctance of foreign investors to fund companies domiciled in India. However, this scenario has changed dramatically. "Yes, there were some regulatory concerns," Mittal acknowledged, "and foreign investors were hesitant to invest in Indian-domiciled companies. But that has changed. Everyone talks a big game, but at the end of the day, everyone is driven by returns. If Indian markets offer better valuations, then suddenly the regulatory environment doesn\'t seem to matter as much." Mittal further pointed out that while regulatory challenges were often cited as the reason for startups moving abroad, the real issue was that Indian markets were not deep or wide enough to support significant growth. Now, with Indian markets demonstrating strong momentum and robustness, many companies are making the move back to India, he said."It\'s great to see this shift," Mittal added, "I hope that this marks the end of the chapter where companies feel the need to be domiciled outside of India. The fact that so many are returning shows just how much the landscape has evolved."Looking to make an impact in the startup ecosystem? Visit https://lnkd.in/dkvpgxWB to see how we can work together.hashtag#startup hashtag#india hashtag#anupammittal hashtag#company hashtag#innovation hashtag#founders hashtag#entrerpreneurs hashtag#Indianstartupnews\n', 'href_map': {'https://lnkd.in/dkvpgxWB': 'https://lnkd.in/dkvpgxWB'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 185574), 'status': 'pending'}
#
#
# {'poster': 'Crio.Do', 'poster_bio': '113,635 followers', 'profile': 'https://www.linkedin.com/school/criodo/posts', 'feed_text': '\n Unlock Your Full Potential as a Backend Developer with Our Learn-By-Doing Program!Build real work-like projects to gain work experience in Java, RestAPI, Spring Boot, and more to land a top career as a backend developer.👨\u200d💻 5 work-like professional projects, with mentorship, to master Backend skills.✅ Build professional projects like the top 1% developers✅ Master the latest backend tech.✅ Crack developer jobs at the best tech companies.\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 187706), 'status': 'pending'}
#
#
# {'poster': 'Linas Beliūnas', 'poster_bio': 'Reinventing Finance 1% at a Time 💸 | Scaling Digital Asset Infrastructure 🚀 | The only newsletter you need for Finance & Tech at 🔔linas.substack.com🔔 | Financial Technology | FinTech | Artificial Intelligence | AI', 'profile': 'https://www.linkedin.com/in/linasbeliunas?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAABbscnUBlKacJbEN5USrYdfhVdH-ffYINJk', 'feed_text': "\n This is wild! After getting laid off from Google, this guy joined Amazon and has done 0 work in 1.5 years 😳And people still wonder how 𝕏 works perfectly fine after Elon Musk laid off 80% of Twitter’s employees...Big Tech is massively inefficient.P.S. for more great stuff, check out 🔔linas.substack.com🔔, it's the only newsletter you need for all things when Finance meets Technology. For founders, builders, and leaders.\n", 'href_map': {'linas.substack.com': 'http://linas.substack.com'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 188762), 'status': 'pending'}
#
#
# {'poster': 'Piyush Somani', 'poster_bio': 'Humour, Sarcasm, Satire, Memes', 'profile': 'https://www.linkedin.com/in/piyushsofunny?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAESXbeYBpBfF7la5c1SpatQoyyPivaAlySI', 'feed_text': '\n Nvidia employees: Sab moh maya hai\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 190773), 'status': 'pending'}
#
#
# {'poster': 'Manish Kapur', 'poster_bio': 'Engineering @Hotstar|Ex-Amazon', 'profile': 'https://www.linkedin.com/in/manish-kapur-4644aa14?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAALroAwBEeihPwnVjM8UWno7nGGR7yyyXjc', 'feed_text': '\n What is this guy upto these days? Trying to be next Elon Musk with tweets ;) I love it though 😂 .. and why stop with "$", lets replace english alphabets with "क\xa0ख\xa0ग\xa0घ\xa0" and numbers with "१ २ ३". Change his company name from OLA to some hindi word. Feel free to add your suggestions in the comments. P.S: I read somewhere he mentioned Elon Musk copies him. I definitely want to smoke what he smoking ;) .P.P.S : Please no gyaan that- he is trying to build in India and we should support him. This is just a fun post and I do support Indian companies taking larger bets. hashtag#ola hashtag#indigenous hashtag#software hashtag#visionary\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 193295), 'status': 'pending'}
#
#
# {'poster': 'Daniel Gasser', 'poster_bio': 'Women! Had ENOUGH of a*hole men mansplaining? Want the best ways to handle mean guys? Which a*hole type you dealing with? Click “Visit my website” for free A*hole Quiz & proven roadmap & tools for dealing with a*holes.', 'profile': 'https://www.linkedin.com/in/daniel-g-gasser?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAA5tVnUBvMTzBoIJxhmVdrxF-Q298IDUXmw', 'feed_text': "\n To All the Hardworking WomenYou work more than ever.But still manage to take care of your home.Sometimes all you want is a break but you can't seem to relax.When you take a break, something always seems to need your attention.Your family comes first but work always seems to be pulling at you too.You're not alone.Remember to take it one day at a time.And there is this group you can join for free and get a moment of peace for yourself.A group that is a safe, free place for you to exchange with other women who share the same experiences.A group that allows you to think and discuss about the life you’re dreaming of building.Some women in the group have already built their dream life and are now in a position to help and support.There are weekly group meetings and Q&A sessions.There are coaches you can talk with and get to know them - also for free.There are group coaching sessions that won't be recorded - the safest group coaching.If you’re interested, write me a message.And, if you want to have a chat with a reformed full-blown a*hole, message me.hashtag#PowerfulWomen hashtag#SafeSpace hashtag#TrustedGuidance\n", 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 194502), 'status': 'pending'}
#
#
# {'poster': 'Anushka Chauhan', 'poster_bio': "Upcoming SWE @Microsoft'24 | Student at Indian Institute of Technology (Banaras Hindu University), Varanasi", 'profile': 'https://www.linkedin.com/in/anushka-chauhan-579a11244?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAADypku0B72_gmKlRbDelQ00vr3yQXh-CIBg', 'feed_text': '\n 🎉Greetings connections, 🎉 This is my first LinkedIn post, and I couldn’t think of a better way to start ✨ . I am absolutely thrilled 🎊  and beyond excited to share this great news 🎉  with you all. I have successfully completed my 8-week summer internship as a Software Engineering Intern at Microsoft. And to top it all off, I have recently received a pre-placement offer from Microsoft 🚀💻! This was nothing short of an incredibly enriching experience offering me a deep dive into a professional environment and allowing me to be a part of Microsoft’s supportive and exceptional work culture . I want to extend my heartfelt thanks to my Manager, Prasad Wagle, for his continuous support, guidance, and encouragement at every step of the internship and a sincere thanks to my mentor Roshan Routray, for the invaluable insights and consistent support which played significant role in the completion of the project. I’m also deeply grateful to my team members, Aman Kumar Gupta, Yash Agarwal , Pawan Jindal, and Prateek Barapatre, for always being there to help me with all my doubts and queries. The team spirit within Azure Service Fabric is truly amazing 🌟 . Over these two months, I’ve gained an amazing wealth of knowledge, and this experience will undoubtedly help me perform better in the future. I would also like to express my gratitude to my incredible alums Lakshya Singh, Shubhangi Choudhary, and Sai Susritha Syamala, for their efforts in navigating me through this new journey every step of the way.Being part of an environment that encourages continuous learning and collaboration has been an incredible experience 💫 , I’m grateful to Microsoft for organizing all those events 🎋 that offered us not just an opportunity to learn but also a chance to connect with so many brilliant minds. I can’t say enough about the incredible work culture here, as I return with an invaluable learning experience filled with fun, growth, and a fresh enthusiasm for what lies ahead! ❤️\n', 'href_map': {'Microsoft': 'https://www.linkedin.com/company/microsoft/', 'Prasad Wagle': '/in/pawagle/', 'Roshan Routray': '/in/roshanroutray/', 'Aman Kumar Gupta': '/in/akg2000/', 'Yash Agarwal': '/in/yashagarwal2304/', 'Pawan Jindal': '/in/pawan-jindal/', 'Prateek Barapatre': '/in/prateekbarapatre/', 'Lakshya Singh': '/in/lakshyasingh11/', 'Shubhangi Choudhary': '/in/shubhangi-choudhary-32a347205/', 'Sai Susritha Syamala': '/in/sai-susritha-syamala-932226218/'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 195845), 'status': 'pending'}
#
#
# {'poster': 'Project Management Institute', 'poster_bio': '1,496,379 followers', 'profile': 'https://www.linkedin.com/company/projectmanagementinstitute/posts', 'feed_text': '\n Find a career that lights you up. Protect our planet as a Project Professional — there’s no limit to the impact you can make.\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 196490), 'status': 'pending'}
#
#
# {'poster': 'Vasanth Bhat', 'poster_bio': '50K+ Followers on LinkedIn | Speaks about frontend and interview preparation |Senior Software Engineer at Walmart Global Tech India', 'profile': 'https://www.linkedin.com/in/careerwithvasanth?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAABUwy1QBpAq94qljJiK8_wMMpdeo7EckLbo', 'feed_text': "\n I dig deeper and got to know changes that Nirmala Sitharaman will introduce in new tax changes.1. The highest tax slab for salaried employees would be 15%.2. New pension scheme for government employees will be cancelled.3. When salaried employees who paid taxes for 3 years or more will get unemployment allowance from the government, if they are laid off.4. Direct tax payers will have reservations on train tickets and fast pass entry in the airport.5. All of our taxes are spent in a transparent manner and roads will be free of potholes.I cannot dig deeper as I woke up after this !! inspired from other posts ! But don't you think the above points are fair to expect from the government?follow me and I will help you to find your dream job: Vasanth Bhat\n", 'href_map': {'Vasanth Bhat': '/in/careerwithvasanth/'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 197253), 'status': 'pending'}
#
#
# {'poster': 'Linas Beliūnas', 'poster_bio': 'Reinventing Finance 1% at a Time 💸 | Scaling Digital Asset Infrastructure 🚀 | The only newsletter you need for Finance & Tech at 🔔linas.substack.com🔔 | Financial Technology | FinTech | Artificial Intelligence | AI', 'profile': 'https://www.linkedin.com/in/linasbeliunas?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAABbscnUBlKacJbEN5USrYdfhVdH-ffYINJk', 'feed_text': '\n 2024 in a nutshell: billionaires increasingly flex on each other by bragging about the size of their AI superclusters instead of the size of their yachts 👇😉Fascinating times.\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 197990), 'status': 'pending'}
#
#
# {'poster': 'Alex Chiou', 'poster_bio': 'Co-Founder @ joinTaro.com, Making Software Engineers Better At Their Jobs', 'profile': 'https://www.linkedin.com/in/alexander-chiou?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAAuZcwoBPlBN2NazFcacZUqv-5tBXFFzglg', 'feed_text': "\n It's incredible to me how massive companies will have 90% automated test coverage, 5 waves of QA, and 3 Jira epics for a feature and still mess up a core flow 20% of users try.On the other hand, Instagram got to 1 billion users with almost 0% test coverage on their Android and iOS apps.This is because if you want to ship quality software, it's much more important to build a culture around quality instead of arbitrary processes to enforce it.Even though Instagram didn't have massive automated testing suites, it did have that culture, backed by some of the best mobile engineers in the world.I saw this culture firsthand working at Instagram for 3 years. It was truly eye-opening and revolutionized how I approach quality.That's why I extensively documented how Instagram's unique but highly effective culture around shipping amazing code works. Make yourself a better engineer by reading it here: https://lnkd.in/g-iUZS94hashtag#techcareergrowth hashtag#softwareengineering hashtag#codequality\n", 'href_map': {'https://lnkd.in/g-iUZS94': 'https://lnkd.in/g-iUZS94'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 198893), 'status': 'pending'}
#
#
# {'poster': 'LinkedIn', 'poster_bio': '27,695,080 followers', 'profile': 'https://www.linkedin.com/company/linkedin/posts', 'feed_text': None, 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 199488), 'status': 'pending'}
#
#
# {'poster': 'Dr. Shishir Gupta', 'poster_bio': 'Funded 134 Startups. Ranked #4 in the World for VC & Startup Consulting | Startup Investment Size: 1 to 30 Cr. | Contact for VC Funding / SME IPO: 25 to 100 Cr.', 'profile': 'https://www.linkedin.com/in/shishir-gupta?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAAGbnF8BFj27Akg8z0_6xt7EDPr1ARoVs-8', 'feed_text': "\n From Newspaper Delivery Boy to Fashion Entrepreneur of a Company worth in Millions.His story of struggle is inspirational. Join me to Congratulate him for the success.Meet Sid Naidu, a true inspiration for anyone who's ever faced adversity!After losing his father at just 11 years old, Sid had to drop out of school and start working to support his family. He began by distributing newspapers, but he didn't let his circumstances define him.Instead, Sid used his struggles as fuel to drive his success. He went on to become a model, and later founded Sid Productions, a fashion and events company that's made a name for itself in the industry.Sid's journey is a reminder that no matter where we come from or what challenges we face, we all have the potential to achieve greatness. Let's take a page out of Sid's book and never give up on our dreams!Share your own story of overcoming adversity in the comments below!hashtag#Inspiration hashtag#Entrepreneurship hashtag#NeverGiveUp hashtag#Fashion hashtag#Events hashtag#SuccessStory hashtag#SidNaidu\n", 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 200525), 'status': 'pending'}
#
#
# {'poster': 'SHOAIB AKHTAR', 'poster_bio': 'SDE-2@DP World | Ex-Goldman Sachs', 'profile': 'https://www.linkedin.com/in/shoaib-akhtar-2331b2191?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAC0OpccB-FiPqWZVYKzXk8CR5DyvHaX_2rg', 'feed_text': "\n After an incredible journey at Goldman Sachs, I'm thrilled to announce that I’ll be taking on a new challenge as a Software Development Engineer II (SDE2) at DP World! 🌟Working at Goldman Sachs has been an amazing experience where I’ve grown both professionally and personally. I want to extend a heartfelt thank you to my manager, Ajay Garg, and my colleagues for their unwavering support.I’d also like to express my gratitude to the Dixit Pujara and the team at DP World for ensuring a smooth onboarding process.As I step into this new chapter at DP World, I'm filled with excitement and enthusiasm to contribute to a dynamic team and continue growing in my career. I’m looking forward to new challenges, innovative projects, and making a meaningful impact.Thank you once again to everyone at Goldman Sachs, and here’s to new beginnings at DP World! 🚀hashtag#NewBeginnings hashtag#SDE2 hashtag#DPWorld hashtag#CareerGrowth hashtag#ThankYou hashtag#Excited hashtag#newjob\n", 'href_map': {'Goldman Sachs': 'https://www.linkedin.com/company/goldman-sachs/', 'DP World': 'https://www.linkedin.com/company/dp-world/', 'Ajay Garg': '/in/ajay-garg-18800810/', 'Dixit Pujara': '/in/dixit-pujara-996503238/'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 201420), 'status': 'pending'}
#
#
# {'poster': 'Salesforce', 'poster_bio': '5,357,521 followers', 'profile': 'https://www.linkedin.com/company/salesforce/posts', 'feed_text': '\n Nobody will remember:• your salary• how "busy" you were• how many hours you workedPeople will remember:• how you spelled it "Sales Force"• that time you @channel\'ed the entire company on Slack • the day you confused "sandbox" with "production" (oops)\n', 'href_map': {'Slack': 'https://www.linkedin.com/company/tiny-spec-inc/'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 202302), 'status': 'pending'}
#
#
# {'poster': 'Global Association of Risk Professionals (GARP)', 'poster_bio': '146,339 followers', 'profile': 'https://www.linkedin.com/company/global-association-of-risk-professionals/posts', 'feed_text': '\n Now is the time to achieve the premier, globally recognized designation in financial risk management.\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 202821), 'status': 'pending'}
#
#
# {'poster': 'Prashant Sachan', 'poster_bio': 'Building AppsForBharat', 'profile': 'https://www.linkedin.com/in/prashantsachan?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAAWfGVgB3Yo8Kgm0caBxBd0Rjh6vy7ooHms', 'feed_text': '\n India has 43 UNESCO World Heritage Sites. Each one has a story to tell about innovation, culture, and achievements that have impacted civilizations around the world.But India’s richness goes far beyond these landmarks. The deeper I explore, the more driven I am to learn, share, and preserve the incredible legacy of the brand ‘Bharat’.That’s why I’ve launched 𝐒𝐚𝐚𝐫𝐭𝐡𝐢, a bi-weekly newsletter where I’ll guide you through:- Lesser-known facts about India, its values, culture and heritage - The "what, why, and how" of early Indian innovations, the practices we still follow, and the traditions we\'ve forgotten- Why technology is crucial to conserve our culture and heritageEach edition will offer fresh perspectives and insights that you might not have come across before on these topics.In this first edition, I talk about the ‘Jaipur Foot Initiative’ and the overall impact it has had on medical tourism in Rajasthan. If you’ve been liking my posts lately, I’m sure you’ll love this one. Subscribe away.\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 203768), 'status': 'pending'}
#
#
# {'poster': 'Adarsh Samalopanan', 'poster_bio': 'Vice President @ Yes Bank Ltd | Ex-HDFC Bank/AGS Transact Technologies Ltd/VsnapU.com | IIM Bg', 'profile': 'https://www.linkedin.com/in/adarsh-samalopanan-024870126?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAB8YdxwBkYK03EjXoJ2E04x_U9C-2P3GcqM', 'feed_text': '\n Some newspaper clippings I saw recently:"Meet Rohan Murty, the only son of Infosys founder and billionaire Narayana Murthy; he doesn\'t want his father\'s 4.8 billion empire.""Akshata Murty, the daughter of Narayana Murthy, wants to build her own identity away from her father\'s wealth.""Sudha Murty, the wife of Narayana Murthy, loves to live a simple life, wear cheap sarees, and shop from local supermarkets."The man worked 70+ hours a week and made 4.8 billion USD, and no one in his family really wants it.\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 204624), 'status': 'pending'}
#
#
# {'poster': 'HackerRank', 'poster_bio': '1,588,653 followers', 'profile': 'https://www.linkedin.com/company/hackerrank/posts', 'feed_text': '\n One bug away from needing real therapy 🙂\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 205105), 'status': 'pending'}
#
#
# {'poster': 'Sell on Amazon (IN)', 'poster_bio': '2,347 followers', 'profile': 'https://www.linkedin.com/company/sellonamazon-india/posts', 'feed_text': '\n Want to be like the top Amazon brands? Don’t miss out on our selling fee drop! Start selling today!\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 205544), 'status': 'pending'}
#
#
# {'poster': 'Andy Greenwell', 'poster_bio': 'SWE III @ Wayfair | Open-sourcing SWE mentorship, one post at a time.', 'profile': 'https://www.linkedin.com/in/ajgreenwell?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAB9yTLUBCkdEac_BPSLfGKpK23Q-ZUYVk3A', 'feed_text': '\n Your PR got rejected.It has 32 comments.And half of them are nits.Don’t- Take personal offense,- Let your ego get involved, and- Argue in the replies all day.Do- Thank them for the feedback,- Offer to hop on a call, and- Resolve the issues in one go.Async communication is great for documenting decisions.But not for resolving conflict.\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 206261), 'status': 'pending'}
#
#
# {'poster': 'Arsh Goyal', 'poster_bio': 'Senior Software Engineer | Samsung | LinkedIn Top Voice ‘24 | Gen AI | Ex- ISRO | Gold Medalist - NIT Jalandhar | Educator - Unacademy | CodeChef | 200k+ YouTube & Instagram', 'profile': 'https://www.linkedin.com/in/arshgoyal?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAACY_mfABFNW6yArgg5K1r5Id8xGpsjdiuA8', 'feed_text': '\n Insane Day at Odoo 🤯Last weekend, I got a chance to witness one of India’s biggest Tech and Business event by Odoo in the tree Capital of India Gandhinagar, Gujarat.The event had upwards of 10,000+ attendees and I got a chance to interact with so many of you. There were keynote sessions and panel discussions by various speakers.Also, met a lot of my fellow creators and it was a great networking opportunity. Events like these help us identify ourselves better and strive for the best.Witnessed booths by multiple service providers and also the job fair for students and those in corporate.Also got a chance to connect with Fabien Pinckaers, Founder at Odoo and share thoughts.Thanks to the entire team at Odoo for making this happen. Kudos 👏🏻hashtag#ocd hashtag#business hashtag#tech hashtag#event hashtag#gujarat\n', 'href_map': {'Odoo': 'https://www.linkedin.com/company/odoo/', 'Fabien Pinckaers': '/in/fpodoo/'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 206928), 'status': 'pending'}
#
#
# {'poster': 'Mansi Singh', 'poster_bio': 'Sr. HR Executive @TGH software Solutions', 'profile': 'https://www.linkedin.com/in/mansi-singh-5b4a8a22b?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAADmldtgBO4f_ytTtMuSlGSYuQfs20CuBuag', 'feed_text': '\n Walk-in Drive for 𝐒𝐨𝐟𝐭𝐰𝐚𝐫𝐞 𝐃𝐞𝐯𝐞𝐥𝐨𝐩𝐞𝐫 Role at TGH Software Solutions Pvt. Ltd.𝐄𝐥𝐢𝐠𝐢𝐛𝐢𝐥𝐢𝐭𝐲 𝐂𝐫𝐢𝐭𝐞𝐫𝐢𝐚:B.Tech / MCA/ B.SCPreferably 2023/22/ 21/20 pass-outs𝐑𝐞𝐪𝐮𝐢𝐫𝐞𝐝 𝐒𝐤𝐢𝐥𝐥𝐬:Strong knowledge of programming languages.𝐖𝐚𝐥𝐤-𝐢𝐧 𝐃𝐫𝐢𝐯𝐞 𝐃𝐞𝐭𝐚𝐢𝐥𝐬 :𝐃𝐚𝐭𝐞: 30th August, 2024𝐓𝐢𝐦𝐞: 12:00 PM to 4:00 PMIf you’re passionate about software development and meet the eligibility criteria, join us for our walk-in drive and seize the opportunity to be part of our innovative team.hashtag#WalkInDrive hashtag#Hiring hashtag#SoftwareDevelopers hashtag#Careers hashtag#Programming hashtag#TechJobs hashtag#TGH\n', 'href_map': {'TGH Software Solutions Pvt. Ltd.': 'https://www.linkedin.com/company/techy-geek-hub/', 'B.Tech': 'http://B.Tech', 'B.SC': 'http://B.SC'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 207836), 'status': 'pending'}
#
#
# {'poster': 'UNIVO Education', 'poster_bio': '47,062 followers', 'profile': 'https://www.linkedin.com/company/univo-ed-tech/posts', 'feed_text': '\n Become a certified cybersecurity professional in just 8 months! Join the Advanced Certification Program in Cybersecurity by E&ICT Academy, IIT Guwahati. Benefit from a comprehensive curriculum, practical learning, and experienced faculty members. Limited slots available! Apply now.\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 208626), 'status': 'pending'}
#
#
# {'poster': 'Shubham Bansal', 'poster_bio': 'Never missed a workout in 1400+ days | IITB', 'profile': 'https://www.linkedin.com/in/shubhambansal?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAAGypPcBrwOuw4A9Cy41qiaVBEmon-71sj0', 'feed_text': "\n In 2006, when I was preparing for IIT, there was a belief - That, Selection depends on Physics & Maths.But, Rank depends on Chemistry.What this means is that - Most students had similar Physics & Maths scores.But,It's Chemistry, that counts.Personally,my P+M score was similar to those who ranked 5000,But,My C score was good and it pushed me under 500.Today,I can see this rule applicable in every aspect of life.Most people work well on weekdays, but,it's the weekend, that counts.Most meals we eat are healthy, but,it's the control of junk, that counts.Most times we are polite & smiling in relationships,but,it's when we get angry, that counts.Most times don't need to care, but, it's when we must care,that counts.Most times ie. 80% of what we do is the samebut,it's the 20%, that counts.Question for readers: Where do you think you are lacking that 20% additional effort in life? and why?Put in comments. **********Follow Shubham Bansal for unfiltered life stories and learnings.\n", 'href_map': {'Shubham Bansal': '/in/shubhambansal/'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 209511), 'status': 'pending'}
#
#
# {'poster': 'Aditya B.', 'poster_bio': 'Experienced Data & Insights Professional', 'profile': 'https://www.linkedin.com/in/imab4u?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAC8DNmUBMJfgb70avi3W4dlgzZRuhZ8qPXg', 'feed_text': '\n - Ordered a Masala dosa from Zomato , paying via Paytm . Shiva Kumar came as delivery guy in place of Ram Kumar. - Booked Uber / Rapido Ride Ganesh came as rider in place of Krishan. Above 2 are hypothetical scenarios. But,There is a significant issue in the market today where individuals registered with companies are different from those actually working on the field. Similarly, vehicles registered with these individuals may not be the same as those being used for work. This can be attributed to various reasons, including:- Migrants lacking identity proofs- Intentional identity concealment for potential criminal activities or to hide a criminal past- Vehicle rental arrangements between individuals of different economic backgrounds- Businesses hiring drivers without thorough background checksThis issue is prevalent in the gig economy, particularly among companies like Swiggy , Rapido , Zomato , Blinkit , Zepto , Uber etc which have grown significantly. To mitigate this risk, these companies must prioritize strict employee background verification.Meanwhile, consumers should exercise extreme caution when dealing with these service providers and be aware of potential security concerns.pc : Google\n', 'href_map': {'Zomato': 'https://www.linkedin.com/company/zomato/', 'Paytm': 'https://www.linkedin.com/company/paytm/', 'Uber': 'https://www.linkedin.com/company/uber-com/', 'Rapido': 'https://www.linkedin.com/company/rapido-bike/', 'Swiggy': 'https://www.linkedin.com/company/swiggy-in/', 'Blinkit': 'https://www.linkedin.com/company/letsblinkit/', 'Zepto': 'https://www.linkedin.com/company/zeptonow/'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 210392), 'status': 'pending'}
#
#
# {'poster': 'Suraj Chawla', 'poster_bio': 'Creator of GPU.net | Physicist turned Entrepreneur', 'profile': 'https://www.linkedin.com/in/ssurajchawla?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAB1tfhYBDLaOR8w_hE4AJuO-Gk_dO8HWtTo', 'feed_text': '\n A quick intro to GPU.net We are entering an AI era,where GPUs will be the new fuel,But GPUs are Capex heavy and need extremely skilled Datacenter operations,With GPU.net you can easily access now,powered by a Decentralised capacity.Opening up our dapp version2.0 shortly.\n', 'href_map': {'GPU.net': 'http://GPU.net'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 211381), 'status': 'pending'}
#
#
# {'poster': 'sukhad anand', 'poster_bio': 'SWE III @Google | Techie007 | Google Summer of Code @2017 | Opinions and views I post are my own', 'profile': 'https://www.linkedin.com/in/sukhad007?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAABorvCkBjwcyfIHXud-7qPyS1OYAZ-3KjfI', 'feed_text': '\n Tech blogs by Netflix are Gold.In June 2022, Netflix geared up for a launch of a new plan - "Basic-with ads" to revive their declining profits. For this feature plan, they simulated the plan weeks ahead of the actual launch just to make sure that the system does not go down. This is just one example, but Netflix is known for high availability and high bar for testing before any launch. Chaosmonkey is one such tool which they built just to randomly bring down services and test how their system behaves in these scenarios.You must go through these articles in which they talk about their various strategies used for testing/launches of various systems:1. Ensuring the Successful Launch of Ads on Netflix: https://lnkd.in/gwYtrHsb2. Sequential A/B Testing Keeps the World Streaming:https://lnkd.in/gxUs57dM3. Introducing SafeTest: A Novel Approach to Front End Testing:https://lnkd.in/g6P-9YcE4. Migrating Netflix to GraphQL Safely:https://lnkd.in/guEB8YNm5. Migrating Critical Traffic At Scale with No Downtime:https://lnkd.in/gB8e6qCV\n', 'href_map': {'https://lnkd.in/gwYtrHsb': 'https://lnkd.in/gwYtrHsb', 'https://lnkd.in/gxUs57dM': 'https://lnkd.in/gxUs57dM', 'https://lnkd.in/g6P-9YcE': 'https://lnkd.in/g6P-9YcE', 'https://lnkd.in/guEB8YNm': 'https://lnkd.in/guEB8YNm', 'https://lnkd.in/gB8e6qCV': 'https://lnkd.in/gB8e6qCV'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 212478), 'status': 'pending'}
#
#
# {'poster': 'Infinite Locus', 'poster_bio': '29,385 followers', 'profile': 'https://www.linkedin.com/company/infinitelocus/posts', 'feed_text': '\n 🏏 A Day of Fun and Team Spirit! 🏏Last Saturday, we took an opportunity to break away from our desks, showcase our teamwork on the field, and have some fun together! Seeing everyone step out, from seasoned players to those just in it for a good time, was truly heartwarming. We shared lots of laughs, cheered each other on, and made some great memories along the way.hashtag#TeamBonding hashtag#CompanyCulture hashtag#BoxCricket\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 213439), 'status': 'pending'}
#
#
# {'poster': 'Takayuki Y.', 'poster_bio': 'Sony - Strategist for Semiconductor Biz (🗾🇯🇵🌸🗻🍣)', 'profile': 'https://www.linkedin.com/in/takayukiyamazaki?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAABDPPlUBRWMXqPNcS3dDABzAPFiIsXEsFS8', 'feed_text': '\n Bipedal humanoid robot replicates human movementshttps://lnkd.in/gbhzfeFW『人間の動きを再現する二足歩行人型ロボット』まずは腕立て伏せから…。hashtag#bipedal hashtag#humanoid hashtag#robot hashtag#mechatronics hashtag#BoosterRobotics hashtag#Booster_Robotics hashtag#二足歩行ロボット\n', 'href_map': {'https://lnkd.in/gbhzfeFW': 'https://lnkd.in/gbhzfeFW'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 214284), 'status': 'pending'}
#
#
# {'poster': 'INDmoney', 'poster_bio': '113,189 followers', 'profile': 'https://www.linkedin.com/company/indmoney/posts', 'feed_text': '\n Start Tracking All Your Money\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 215438), 'status': 'pending'}
#
#
# {'poster': 'Rise Radiant', 'poster_bio': '35 followers', 'profile': 'https://www.linkedin.com/company/riseradiant/posts', 'feed_text': '\n Bhavish Aggarwal Suggests Elon Musk Should Explore New Ventures, At the BT India@100 Conclave in New Delhi, Bhavish Aggarwal, Founder and CEO of Ola , offered some intriguing advice to Elon Musk, suggesting he might benefit from exploring different business ventures. When asked about comparisons to Musk, Aggarwal remarked, "I’m much younger than him, and I’m not sure why he’s venturing into the same businesses I’m in. Maybe he should try something new for a change." Aggarwal emphasized that Ola\'s mission is to revolutionize India\'s digital ecosystem, specifically focusing on the needs of the global south. He proudly mentioned Ola Electric\'s establishment of India\'s first Gigafactory and the launch of Krutrim, Ola\'s AI venture, which he began before Musk\'s own AI initiatives. In a nod to his cultural roots, Aggarwal quipped, "We prefer the kurta-pyjama over a leather jacket any day. If people in Silicon Valley can wear leather jackets and black polo t-shirts, why can’t we wear a kurta and have long hair?"Aggarwal also drew a distinction between the markets Tesla and Ola serve, stating, "Tesla is for the West, Ola is for the rest." With Ola Cabs, Ola Electric, and now Krutrim, Aggarwal aims to build products tailored for India and the broader global south, offering a more inclusive and locally relevant approach to technology and innovation.Rise Radianthashtag#BhavishAggarwal hashtag#Ola hashtag#ElonMusk hashtag#Startups hashtag#IndiaInnovation hashtag#Krutrim hashtag#Gigafactory hashtag#DigitalEcosystem hashtag#GlobalSouth hashtag#TechLeadership\n', 'href_map': {'Ola': 'https://www.linkedin.com/company/olacabs-com/', 'Rise Radiant': 'https://www.linkedin.com/company/riseradiant/'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 216452), 'status': 'pending'}
#
#
# {'poster': 'Ankita Das', 'poster_bio': 'HR - Business Partner at Flipkart', 'profile': 'https://www.linkedin.com/in/ankita-das-38445319a?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAC6yO1QBstVwNEfSy686IhHpIDia6yOdHxQ', 'feed_text': '\n Urgent Hiring !!Flipkart is Hiring  for Client Relationship Executives (CRE) Locations : Bangalore, Delhi, MumbaiAbout the Role: As a Client Relationship Executive (CRE) at Flipkart, you will play a pivotal role in nurturing and enhancing relationships with our key clients. Your primary responsibility will be to understand client needs, ensure seamless execution of logistics and supply chain services, and address any concerns or issues promptly. You will also provide regular updates on order status, delivery timelines, and service improvements. As the primary point of contact for our clients, you will ensure high levels of customer satisfaction and collaborate closely with internal teams to meet client requirements efficiently and effectively.Experience Required:Freshers or candidates with relevant work experience are welcome to apply. Logistics background preferred in case of work experience.Skills Required:Strong Communication SkillsCustomer Relationship ManagementBasic to intermediate Excel SkillsProblem-SolvingTime ManagementAttention to DetailMultitaskingInterested candidates can apply by filling out the form link below:https://lnkd.in/g9wxf6_VReetik Abhishekhashtag#flipkarthiring hashtag#logisticjobs hashtag#flipkart hashtag#urgenthiring\n', 'href_map': {'https://lnkd.in/g9wxf6_V': 'https://lnkd.in/g9wxf6_V', 'Reetik Abhishek': '/in/reetik-abhishek-33985b165/'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 217493), 'status': 'pending'}
#
#
# {'poster': 'Neha Rathore', 'poster_bio': 'Head - HR @Tagbox I People Matters | Strategic HR | HRBP | Talent Acquisition | HR compliance Talks about #hrbps #hrtrends #hranalytics #hrbusinesspartnering #humancapitalmanagement', 'profile': 'https://www.linkedin.com/in/neha-rathore-94b3a67b?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAABD3K8sBMUUGZPALjrxw-7FIsC6IMbntW70', 'feed_text': '\n hashtag#hiring\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 218675), 'status': 'pending'}
#
#
# {'poster': 'Syed Akram Hossain, AIPM', 'poster_bio': 'Corporate HR Professional', 'profile': 'https://www.linkedin.com/in/syed-akram-hossain-aipm-40077697?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAABSUpcABQ6_wS2V_nN1oVKKIWN2X-osqIo4', 'feed_text': '\n 🎆 "Amazing work- Beauty emerging through broken mirrors & glass."hashtag#work hashtag#amazing hashtag#glass hashtag#beauty hashtag#broken🎥 video source: hashtag#socialmedia Like👍 | Comment🪧 | Share ♻️🔎 Follow Syed Akram Hossain, AIPM\n', 'href_map': {'Syed Akram Hossain, AIPM': '/in/syed-akram-hossain-aipm-40077697/'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 220179), 'status': 'pending'}
#
#
# {'poster': 'Binay Bhattacharya', 'poster_bio': 'IIT KGP | Humour & Startups | Strategy @ Venwiz', 'profile': 'https://www.linkedin.com/in/binay-bhattacharya-56a209150?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAACRWl-IBRwUFefX23sD9X3KljZUB_N4tlMM', 'feed_text': "\n Nvidia employees are millionaires but stillcan't spend their money due to work loadluckiest people on Earth are the spouses of Nvidia employeeshashtag#humour hashtag#startup\n", 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 221456), 'status': 'pending'}
#
#
# {'poster': 'Kinshul Singhal', 'poster_bio': "V Guard || MBA IIM KASHIPUR'24 || Director's Merit List Award || Finance", 'profile': 'https://www.linkedin.com/in/kinshul-singhal-29571018a?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAACyZhpEBjCeg-YTqvgn6qdceAUjQ9K5t-Iw', 'feed_text': '\n Thank you for having me for this session. Seeing IIM Kashipur students interact is the best thing, something that will be close to my heart.Hope people have gained some great insights from the session. Happy to contribute as an alumni.\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 222562), 'status': 'pending'}
#
#
# {'poster': 'Ryan Peterman', 'poster_bio': 'AI/ML Infra @ Meta | Writing About Software Engineering & Career Growth', 'profile': 'https://www.linkedin.com/in/ryanlpeterman?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAABRr6bcBeNKKOULohu05Bu_ivPE7lKI981c', 'feed_text': "\n I told a mentee to turn down a $50,000 compensation bump from an offer at Google.Google's offer would give him more money but keep him at the same level he had at Meta.I told him to turn it down because he was learning a lot in his current role and had a strong path to getting promoted soon.Short-term compensation bumps in exchange for slower career growth will earn you less over your career.Promotions are one of the strongest drivers of higher compensation. Examples from Google's comp on levels.fyi:• New Grad - $190,209• Mid-level - $284,702• Senior - $390,286• Staff - $549,000Each promotion will grow your compensation by around $100,000 in big tech. Those increases only grow as you become more senior.Focusing on growth over your short-term comp (especially if you're early in your career) will earn you more in the long term.Therefore, go where you think you'll grow the fastest as long as the compensation difference isn't ridiculous. And about my mentee, they stayed and got promoted to Senior within 6 months of our conversation.\n", 'href_map': {'levels.fyi': 'http://levels.fyi'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 223960), 'status': 'pending'}
#
#
# {'poster': 'Apurv Anand Tekriwal', 'poster_bio': 'Senior Category Manager @ Flipkart| Ex.Godrej & Gulf Oil', 'profile': 'https://www.linkedin.com/in/apurv-anand-tekriwal-3aa156b2?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAABfe67IBOzBf7sgwA9p60el4jv4tLeJw1OY', 'feed_text': '\n !!Hiring Alert!!📌 Flipkart is hiring for Manager Role : Business Planning Location : Bangalore ( Work From Office)Skills: Business Planning, Category Management, Data AnalysisMinimum experience of 3-5 years with background in E-Com would be preferred but not necessary If you are interested, please mail me the resume with title of the message as "Manager : Business Planning role" at apurv.tekriwal@flipkart.com\n', 'href_map': {'apurv.tekriwal@flipkart.com': 'mailto:apurv.tekriwal@flipkart.com'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 225549), 'status': 'pending'}
#
#
# {'poster': 'Chad Baker', 'poster_bio': 'Fleet Safety Pro 🚚 | Phone Assassin 📲 | Sales Science 🧬', 'profile': 'https://www.linkedin.com/in/chad-baker-288596139?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAACG5TwgB_fmjdBKz0WeRA90NrRwsJSkMRKY', 'feed_text': "\n I have been working remotely from home for almost 3 years now.And you are not going to believe the realization that I have just come to. I believe that I am outputting at least 3x the amount of work + productivity that I would have been, had I been in an office this whole time. Let me break it down more for you:- no commute- no distractions- no prolonged margarita lunch breaks- peace and silence- easy to multi taskHad I been in office with tons of other people and distractions, there is just no way I would get even half the amount of work that I do now done.I understand there is energy in being with other folks IRL.That's where company events and IRL trainings come into play.Remote work allows me to go hard all day.And that right there drives revenue. Remote work allows you to put yourself in a position where you can't be stopped.At least for me. What is your company's remote work policy?hashtag#remote hashtag#remotework hashtag#sales hashtag#productivity hashtag#wfh hashtag#office hashtag#events\n", 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 226827), 'status': 'pending'}
#
#
# {'poster': 'Novonesis', 'poster_bio': '237,616 followers', 'profile': 'https://www.linkedin.com/company/novonesis/posts', 'feed_text': '\n Have you taken a bite out of Novonesis today? Our colleague Jacob Paulsen takes the challenge to explain our Food & Beverage Biosolutions in a 90-second elevator pitch. "Today, several billion consumers around the world consume a food and beverage product with an ingredient from Novonesis. We provide taste, texture and health benefits while allowing producers to get more from the raw material and reducing food waste," he says. In the video, Jacob talks about examples of the products that are made with our biosolutions, and he wraps up how we are helping customers in the food and beverage sector:\xa0"With the right combination of cultures, enzymes and expertise, we help producers all over the world transform raw materials into great food and beverage products."hashtag#biosolutions hashtag#foodandbeverage hashtag#enzymes hashtag#cultures hashtag#novonesis\n', 'href_map': {'Jacob Paulsen': '/in/jacob-paulsen/'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 227515), 'status': 'pending'}
#
#
# {'poster': 'Animesh Jain', 'poster_bio': 'Group product manager | Product mentor | Tata 1mg | Ex-Ninjacart | Ex-Toppr | IIT Guwahati', 'profile': 'https://www.linkedin.com/in/animeshjain1996?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAABbmGmkBn8uwGajpXATyPtOJVK28t9MEZVY', 'feed_text': "\n Did you see Zomato's genius with the Dua Lipa move?Step 1 - Launch District (+ acquire Paytm's ticketing business)Step 2 - Relaunch Feeding India concert. Bring a huge name (Dua Lipa) to the lineupStep 3 (highly likely) - Sell the concert tickets on DistrictWith the Feeding India concert (a CSR initiative) by the parent company (Zomato), they are giving District (their latest baby) a platform to shine and acquire lakhs of users.What a start it would be for District! Customer acquisition strategy at its finest.I can already see the ticketing business getting disrupted big time. Super excited to see that happening.Did I miss anything here? Or is this really a genius move in the making? Share in the comments!\n", 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 228538), 'status': 'pending'}
#
#
# {'poster': 'Ketan Goel', 'poster_bio': 'Strategy |Problem Solving | Analytics | People Management |', 'profile': 'https://www.linkedin.com/in/kg97?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAB6IapwBiaKY7tkxIe4WpAT4dgOmP12vS7Y', 'feed_text': '\n Ola is hiring for Business Analyst (1-4 years of experience) Experience & Required QualificationsStrong analytical and problem-solving skillsHands-on experience with SQL, R, and Excel/SheetsGood understanding of mobile and internet productsPreferred Industry: Retail, EdTech, Newage startups, eCommerce\n', 'href_map': {'Ola': 'https://www.linkedin.com/company/olacabs-com/'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 229221), 'status': 'pending'}
#
#
# ...
#
#
# {'poster': 'The Valuation School', 'poster_bio': '75,467 followers', 'profile': 'https://www.linkedin.com/company/thevaluationschool/posts', 'feed_text': "\n Top Tax-Saving Investments.Let's understand more about tax-saving investment options in India in the post below!---------------------------------------------------Comment down your thoughts👇Follow The Valuation School for more amazing contentSave this post for later ✅Repost to help others 🔁hashtag#finance hashtag#investmentbanking hashtag#linkedin Parth\n", 'href_map': {'The Valuation School': 'https://www.linkedin.com/company/thevaluationschool/', 'Parth': '/in/caparthverma/'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 329405), 'status': 'pending'}
#
#
# {'poster': 'Job Portal by GeeksforGeeks', 'poster_bio': '446,775 followers', 'profile': 'https://www.linkedin.com/company/geeksforgeeks-jobs/posts', 'feed_text': '\n 😳\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 329805), 'status': 'pending'}
#
#
# {'poster': 'Akshay Saini 🚀', 'poster_bio': 'Founder, NamasteDev | Teacher | YouTuber (1.5Million+)', 'profile': 'https://www.linkedin.com/in/akshaymarch7?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAAydGsYBV8jlkPC_2Z6r5yjoiWBGKxwrPpg', 'feed_text': "\n Don't hesitate to admit when you're wrong. In the world of programming, bugs don't get fixed by ignoring them. Admitting your mistakes is the first step to learning and becoming a better developer.\n", 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 330463), 'status': 'pending'}
#
#
# {'poster': 'Hamna Aslam Kahn', 'poster_bio': "Follow me to get insights on how to use AI at work and beyond. Join the world's biggest AI newsletter with 700K+ readers ↓", 'profile': 'https://www.linkedin.com/in/hamna-aslam-kahn?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAACDcftYBya1_DOU8CVR9Nj81cbIpJ8KcFJw', 'feed_text': "\n ChatGPT might be popular for research.But this new alternative is RELIABLE and 10x better. Here's how you can use it: Otio - the best AI research and writing tool I've ever tested.Unlike typical AI chatbots, it's built specifically for research.It's my super smart assistant for summarizing, chatting with docs, writing, editing, and paraphrasing.Try now: https://lnkd.in/de9rX79GHope you found this helpful.____If you liked this and want to keep up with the latest AI tools, trends and news sign up for Superhuman AI: https://lnkd.in/dEmezNQ2\n", 'href_map': {'Otio': 'https://www.linkedin.com/company/otioai/', 'https://lnkd.in/de9rX79G': 'https://lnkd.in/de9rX79G', 'https://lnkd.in/dEmezNQ2': 'https://lnkd.in/dEmezNQ2'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 331162), 'status': 'pending'}
#
#
# {'poster': 'incident.io', 'poster_bio': '8,408 followers', 'profile': 'https://www.linkedin.com/company/incident-io/posts', 'feed_text': "\n We’ve all been there—an incident happens, and you're pretty sure you know who’s behind it. But how do you keep the team focused on fixing the system instead of pointing fingers? \U0001faf5\xa0🤔At SEV0, Andrew Guenther, OpenAI Technical Staff Member, is tackling this head-on with the session: maintaining a blameless culture when everyone knows whodunnit. ⚡️Whether you’re new to incident management or have been in the game for years, this session is all about helping your team learn and grow—without the blame game. Come join us and let’s figure it out together. 🦾Link to register and view the full agenda below 👀hashtag#SEV0\n", 'href_map': {'Andrew Guenther': '/in/andrewguenther/', 'OpenAI': 'https://www.linkedin.com/company/openai/'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 331809), 'status': 'pending'}
#
#
# {'poster': 'Anmol Agarwal', 'poster_bio': 'SDE-2 at Uber | 37K+ followers | DM for referrals | NSIT(now NSUT) | Mentor | Singer and Guitarist | Teacher | Youtuber | Competitive programmer | React | Golang | Fullstack | Freelance | 30+ bookings on topmate', 'profile': 'https://www.linkedin.com/in/anmol-agarwal-674a21166?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAACephHgBBc7W5aqYX3cSL1I4GeTlfgKloM8', 'feed_text': '\n The only person I hate is the one who won’t accept O(nlogn) solution and will keep on insisting O(n) solution in an interview. And will reject you after😅.hashtag#humour\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 332465), 'status': 'pending'}
#
#
# {'poster': 'Google', 'poster_bio': '33,893,632 followers', 'profile': 'https://www.linkedin.com/company/google/posts', 'feed_text': '\n Tara, an associate product marketing management intern at Google, spoke with a panel of Google Interns to learn more about their experience this summer ➡️ https://goo.gle/3Xa3Fz8\n', 'href_map': {'https://goo.gle/3Xa3Fz8': 'https://goo.gle/3Xa3Fz8'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 332862), 'status': 'pending'}
#
#
# {'poster': 'Bibin Wilson', 'poster_bio': 'DevOps Tips & Guides | Co-Founder @CrunchOps - DevOps Consulting', 'profile': 'https://www.linkedin.com/in/bibinwilson?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAAN4avEBvsg_7CdVU6xZKjxoWNtQ0w0nKyY', 'feed_text': "\n DevOps/SRE challenge 👇 How would you go about troubleshooting this 503 error if you were part of ChatGPT's DevOps/SRE team?Assume the whole mircoservice stack is deployed on Kubernetes.- What monitoring and alerting systems could be implemented to detect and notify about such service outages proactively?- What  strategies would you  implement for high availability to minimize the occurrence of 503 errors.- How will you design a graceful degradation or fallback mechanism for when the main service becomes unavailable?- What pattern would you use to prevent cascading failures that could lead to 503 errors.Drop your thoughts in the comments below and see how others in the DevOps community would approach this! Let’s learn from each other and build stronger systems together.----Join Over 7,000+ DevOps EngineersGet exclusive insights, tips, and the latest DevOps trends delivered straight to your inbox every week.𝗦𝗶𝗴𝗻 𝘂𝗽 𝗳𝗼𝗿 𝗙𝗿𝗲𝗲: https://lnkd.in/gg6cbhSG𝗡𝗼𝘁𝗲: This is the actual 503 error from ChatGPT website.hashtag#devops hashtag#SRE hashtag#systemdesign\n", 'href_map': {'https://lnkd.in/gg6cbhSG': 'https://lnkd.in/gg6cbhSG'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 333505), 'status': 'pending'}
#
#
# {'poster': 'Bhavye Khetan', 'poster_bio': 'Growth & Data', 'profile': 'https://www.linkedin.com/in/bhavyekhetan?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAADBdlUYBs8it0XVrSpKd22C1zIwV4WGfMdQ', 'feed_text': "\n VC's are back. Vacation's over. If you are a Pre-Seed/ Seed founder looking to raise, I got you. Got a list of 600+ venture funds investing right now. Comment your email and will send it 💰 hashtag#funding hashtag#vc hashtag#preseed hashtag#seed hashtag#founders hashtag#startups hashtag#raisingmoney\n", 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 334204), 'status': 'pending'}
#
#
# {'poster': 'Nagarro', 'poster_bio': '1,281,763 followers', 'profile': 'https://www.linkedin.com/company/nagarro/posts', 'feed_text': "\n Curious about the future of tech? In our latest hashtag#NagarroNuggets, uncover the power of quantum computing with Rahul Mahajan. Learn how it’s revolutionizing industries and dive into the exciting work happening at our Qlab, where we're thinking 'Quantum' breakthroughs.hashtag#FluidicEnterprise\n", 'href_map': {'Rahul Mahajan': '/in/mahajanmaha/'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 334624), 'status': 'pending'}
#
#
# {'poster': 'Ketan Goel', 'poster_bio': 'Strategy |Problem Solving | Analytics | People Management |', 'profile': 'https://www.linkedin.com/in/kg97?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAB6IapwBiaKY7tkxIe4WpAT4dgOmP12vS7Y', 'feed_text': '\n We are looking to hire for multiple Analytics positions at Meesho.Business Analyst  [0-2 Years of Experience]Senior Business Analyst [ 2-4 Years of Experience]Lead Business Analyst [4-6 Years of Experience]Analytics Manager [6+ Years of Experience]If interested, Please share your details in google form[Link in comments]Do Share in your network!If interested, You can fill out the google form in comments.\n', 'href_map': {}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 335080), 'status': 'pending'}
#
#
# {'poster': 'Superpowered Designers', 'poster_bio': '549 followers', 'profile': 'https://www.linkedin.com/company/superpowereddesigners/posts', 'feed_text': "\n Coding for Designers (No BS) - AI MasterclassTurn your videos into live streams with Restream https://restre.am/ANImHave you ever had a crazy idea that you've always wanted to build but didn't know where to start?What if I told you that the days of coding from scratch are over? With some well-crafted prompts and adjustments, you can now build quick MVPs with ease.In this session, I'm going to show you how to code a few interactions just by talking to ChatGPT.Whether you're a newbie or a veteran, this is going to blow your mind.\n", 'href_map': {'https://restre.am/ANIm': 'https://restre.am/ANIm'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 335685), 'status': 'pending'}
#
#
# {'poster': 'Visa', 'poster_bio': '1,741,379 followers', 'profile': 'https://www.linkedin.com/company/visa/posts', 'feed_text': '\n Join us at the Global Fintech Fest 2024! We’re thrilled to be part of the conversations on the exciting convergence of banking and payments. Visit booth Q8- Q15 to witness the launch of solutions that will transform India’s digital payments’ landscape. To learn more about the conference, visit: https://vi.sa/3RoX5CzSandeep Ghosh Sujai Raina Ramakrishnan Gopalan Rishi Chhabrahashtag#GlobalFintechFest2024 hashtag#VisaInnovations hashtag#FutureOfPayments\n', 'href_map': {'Global Fintech Fest': 'https://www.linkedin.com/company/globalfintechfest/', 'https://vi.sa/3RoX5Cz': 'https://vi.sa/3RoX5Cz', 'Sandeep Ghosh': '/in/sandeep-ghosh-55ab73/', 'Sujai Raina': '/in/sujairaina/', 'Ramakrishnan Gopalan': '/in/ramakrishnan-gopalan-a909062/', 'Rishi Chhabra': '/in/rishichhabra/'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 336169), 'status': 'pending'}
#
#
# {'poster': 'Jas Sharma', 'poster_bio': 'Pythonist | Data Analytics & Supply Chain Management enthusiast| Passionate in Robotics, Machine Learning & Deep Learning for Predictive Forecasting | Proficient in XAI Frameworks |', 'profile': 'https://www.linkedin.com/in/jas-sharma-217614233?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAADpKJTMBPIzlFJY4iUWzxfvz7zQaku5CAHU', 'feed_text': "\n How I tried to turn llama 3.1 to chatgpt 4/4o ?Extending LLaMA 3.1 Capabilities: Automated Data Analysis and Chart Creation with NLP.Preventing Token Issues by Using Dataset PreviewsI’m excited to share a project I've been working on: extending the capabilities of LLaMA 3.1 to function much like ChatGPT-4.0, but with a twist—it can now automatically generate charts and insights from your entire dataset without needing to upload the whole dataset in the prompt. Instead, only a preview of the dataset is used to prevent token-related issues, and the generated code is then applied to the full dataset! 📈A big shoutout to Tejasvi Arneja just telling me the problem , which led to the idea of extending this capability to the whole dataset, making the analysis even more robust:1. Automatic Chart Creation using : Just upload your dataset (CSV or Excel), and LLaMA 3.1 now generates Python code to produce relevant charts for the entire dataset, providing comprehensive insights without any manual intervention.2.  Real-Time Execution using exec() : The generated code is executed instantly and automatically , offering real-time visualizations and insights directly in the interface.3.  Smart Feedback Loop : If an error occurs during execution, it's fed back into LLaMA, which automatically corrects the code, ensuring a smoother and more accurate analysis process—just like ChatGPT 4 and 4o feedback mechanism.4. Token Efficiency : By using only a dataset preview in the prompt, LLaMA 3.1 avoids hitting token limits, while the generated code is still applied to the full dataset for comprehensive analysis.5. User-Friendly Interaction : You can interact with LLaMA 3.1 in a conversational manner, asking it to analyze your data and create visualizations on the fly—similar to what ChatGPT-4.0 can do.This extension doesn’t just add functionality; it makes data analysis more accessible by reducing the need for coding expertise. It’s an exciting development that showcases how LLaMA can be adapted to meet specific needs, pushing the boundaries of what's possible with AI. 💡Looking forward to exploring more ways to innovate and improve user experiences in the AI space!hashtag#Ai hashtag#machinelearning hashtag#datascience hashtag#llm #Here is a preview of how my extension works: Note : this is a hybrid approach utilizing your system with libraries to automate the process but if deployed in a cloud environment it will work the same. Your suggestions are appreciated !!\n", 'href_map': {'Tejasvi Arneja': '/in/tejasviarneja21/'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 336717), 'status': 'pending'}
#
#
# {'poster': 'Vivek Lohcheb', 'poster_bio': 'CEO @ Pincode', 'profile': 'https://www.linkedin.com/in/viveklohcheb?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAABno54IBKCEcHr1BvST63lvBQgBRfvXzlyA', 'feed_text': '\n Phonepe grows profitably by achieving more than 5000 Cr and adj. PAT of about 200 Cr in FY 23-24.https://lnkd.in/gn56fsPJhashtag#Phonepe\n', 'href_map': {'https://lnkd.in/gn56fsPJ': 'https://lnkd.in/gn56fsPJ'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 337384), 'status': 'pending'}
#
#
# {'poster': 'Haneet Singh', 'poster_bio': 'Senior Talent Partner at Adobe – Featured at Billboard Times Square | Talent Trekker l Accessibility Envangelist l 42K+ Linkedin Fam l Linkedin Global TA Voice 🏆 | Mentor @topmate🏅', 'profile': 'https://www.linkedin.com/in/haneet-singh-71261570?miniProfileUrn=urn%3Ali%3Afsd_profile%3AACoAAA8Kfr4BPGGYwoCjR6Svyqa806cjW-Fh-pk', 'feed_text': '\n We’re Hiring: Talent Partner (Contract role) for Adobe Bangalore!Are you a seasoned Talent Partner with 6-10 years of experience? Join our team in Bangalore and shape our talent strategy while driving recruitment efforts.Key Responsibilities:- Develop and implement effective talent acquisition strategies.- Lead the full recruitment lifecycle.- Act as a recruitment consultant for Business.- Build strong relationships with hiring managers.- Utilize data and insights for recruitment decisions.Requirements:- 6-10 years of talent acquisition or HR experience.- Proven success in managing recruitment processes.- Strong communication and interpersonal skills.- Ability to excel in a fast-paced environment.Passionate about talent acquisition? Seeking an exciting opportunity in Bangalore? DM your resume and we will connect.hashtag#Hiring hashtag#TalentPartner hashtag#Recruitment hashtag#BangaloreJobs hashtag#HR hashtag#TalentAcquisition hashtag#StrategicrecruitmentMaria Leena Dpaul PSRP Kiran\n', 'href_map': {'Maria Leena Dpaul': '/in/maria-leena-dpaul-7a6b0223/', 'PSRP Kiran': '/in/psrp-kiran/'}, 'createdAt': datetime.datetime(2024, 8, 27, 15, 54, 28, 338147), 'status': 'pending'}

# %%
# # Extracting the HTML of the complete introduction box
# # that contains the name, company name, and the location
# feeds = soup.find_all('div', {'class': 'feed-shared-update-v2__description-wrapper'})

# %%
    
# feed_texts = [ feed.find('span', {'class': 'break-words tvm-parent-container'}) for feed in feeds]
# for feed_text in feed_texts:
#     print(feed_text.get_text())
#     print(feed_text.get_text().find("hiring"))
#     print("\n")

# %%
# Given text
# given_text = nlp("🚀 We're Hiring! Join Our Dynamic Team! We're excited to announce that [Company Name] is expanding, and we're looking for passionate individuals to join us. If you're someone who thrives in a fast-paced environment and loves solving challenging problems, we want to hear from you! Open Positions:Software EngineerLocation: [City, Country]Apply HereData ScientistLocation: [City, Country]Apply HereProduct ManagerLocation: [City, Country]Apply HereWhy [Company Name]?Competitive salary and benefitsOpportunity to work with a talented teamFlexible working hours and remote work optionsProfessional development and growth opportunitiesInterested?Click on the links above to apply or visit our Careers Page. Share this post with anyone who might be a great fit! Let's build something amazing together.#Hiring #JobOpportunity #JoinOurTeam #TechJobs")
# given_text2=nlp("I am a passionate Computer Engineering student with a minor in Artificial Intelligence, currently seeking full-time Software Engineering roles. I have experience in developing and optimizing software solutions, with strong skills in C/C++, SQL, JavaScript, ReactJs, Node.js, and database management (SQL, NoSQL). I am particularly interested in positions that involve: Backend development using Node.js and SQL/NoSQL databases. API development and optimization for scalable applications. Collaborative projects in agile environments. Opportunities for growth in machine learning and AI integration. I have a proven track record of success, including leading teams in hackathons and internships where I contributed to significant performance improvements. I am looking for a role where I can leverage my technical skills and leadership abilities to contribute to innovative projects. If your company is hiring for roles that match these interests, I would love to connect! #SoftwareEngineering #BackendDevelopment #NodeJS #AI #APIDevelopment #TechJobs #Hiring");
# # Filter texts based on similarity
# threshold = 0.7  # Set your threshold

# filtered_texts = [post for post in posts if post["feed_text"] and given_text.similarity(nlp(post["feed_text"])) > threshold]


# for feed_text in filtered_texts:
#     print(feed_text)
#     print("\n")

# %%
# SAVE THE DATA TO THE MONGO DB

# %%
db = client["posts"]
posts_collection = db["posts"]

# %%
posts_collection.insert_many(posts)
# Out:
# InsertManyResult([ObjectId('66cdf6beac711620f52864fc'), ObjectId('66cdf6beac711620f52864fd'), ObjectId('66cdf6beac711620f52864fe'), ObjectId('66cdf6beac711620f52864ff'), ObjectId('66cdf6beac711620f5286500'), ObjectId('66cdf6beac711620f5286501'), ObjectId('66cdf6beac711620f5286502'), ObjectId('66cdf6beac711620f5286503'), ObjectId('66cdf6beac711620f5286504'), ObjectId('66cdf6beac711620f5286505'), ObjectId('66cdf6beac711620f5286506'), ObjectId('66cdf6beac711620f5286507'), ObjectId('66cdf6beac711620f5286508'), ObjectId('66cdf6beac711620f5286509'), ObjectId('66cdf6beac711620f528650a'), ObjectId('66cdf6beac711620f528650b'), ObjectId('66cdf6beac711620f528650c'), ObjectId('66cdf6beac711620f528650d'), ObjectId('66cdf6beac711620f528650e'), ObjectId('66cdf6beac711620f528650f'), ObjectId('66cdf6beac711620f5286510'), ObjectId('66cdf6beac711620f5286511'), ObjectId('66cdf6beac711620f5286512'), ObjectId('66cdf6beac711620f5286513'), ObjectId('66cdf6beac711620f5286514'), ObjectId('66cdf6beac711620f5286515'), ObjectId('66cdf6beac711620f5286516'), ObjectId('66cdf6beac711620f5286517'), ObjectId('66cdf6beac711620f5286518'), ObjectId('66cdf6beac711620f5286519'), ObjectId('66cdf6beac711620f528651a'), ObjectId('66cdf6beac711620f528651b'), ObjectId('66cdf6beac711620f528651c'), ObjectId('66cdf6beac711620f528651d'), ObjectId('66cdf6beac711620f528651e'), ObjectId('66cdf6beac711620f528651f'), ObjectId('66cdf6beac711620f5286520'), ObjectId('66cdf6beac711620f5286521'), ObjectId('66cdf6beac711620f5286522'), ObjectId('66cdf6beac711620f5286523'), ObjectId('66cdf6beac711620f5286524'), ObjectId('66cdf6beac711620f5286525'), ObjectId('66cdf6beac711620f5286526'), ObjectId('66cdf6beac711620f5286527'), ObjectId('66cdf6beac711620f5286528'), ObjectId('66cdf6beac711620f5286529'), ObjectId('66cdf6beac711620f528652a'), ObjectId('66cdf6beac711620f528652b'), ObjectId('66cdf6beac711620f528652c'), ObjectId('66cdf6beac711620f528652d'), ObjectId('66cdf6beac711620f528652e'), ObjectId('66cdf6beac711620f528652f'), ObjectId('66cdf6beac711620f5286530'), ObjectId('66cdf6beac711620f5286531'), ObjectId('66cdf6beac711620f5286532'), ObjectId('66cdf6beac711620f5286533'), ObjectId('66cdf6beac711620f5286534'), ObjectId('66cdf6beac711620f5286535'), ObjectId('66cdf6beac711620f5286536'), ObjectId('66cdf6beac711620f5286537'), ObjectId('66cdf6beac711620f5286538'), ObjectId('66cdf6beac711620f5286539'), ObjectId('66cdf6beac711620f528653a'), ObjectId('66cdf6beac711620f528653b'), ObjectId('66cdf6beac711620f528653c'), ObjectId('66cdf6beac711620f528653d'), ObjectId('66cdf6beac711620f528653e'), ObjectId('66cdf6beac711620f528653f'), ObjectId('66cdf6beac711620f5286540'), ObjectId('66cdf6beac711620f5286541'), ObjectId('66cdf6beac711620f5286542'), ObjectId('66cdf6beac711620f5286543'), ObjectId('66cdf6beac711620f5286544'), ObjectId('66cdf6beac711620f5286545'), ObjectId('66cdf6beac711620f5286546'), ObjectId('66cdf6beac711620f5286547'), ObjectId('66cdf6beac711620f5286548'), ObjectId('66cdf6beac711620f5286549'), ObjectId('66cdf6beac711620f528654a'), ObjectId('66cdf6beac711620f528654b'), ObjectId('66cdf6beac711620f528654c'), ObjectId('66cdf6beac711620f528654d'), ObjectId('66cdf6beac711620f528654e'), ObjectId('66cdf6beac711620f528654f'), ObjectId('66cdf6beac711620f5286550'), ObjectId('66cdf6beac711620f5286551'), ObjectId('66cdf6beac711620f5286552'), ObjectId('66cdf6beac711620f5286553'), ObjectId('66cdf6beac711620f5286554'), ObjectId('66cdf6beac711620f5286555'), ObjectId('66cdf6beac711620f5286556'), ObjectId('66cdf6beac711620f5286557'), ObjectId('66cdf6beac711620f5286558'), ObjectId('66cdf6beac711620f5286559'), ObjectId('66cdf6beac711620f528655a'), ObjectId('66cdf6beac711620f528655b'), ObjectId('66cdf6beac711620f528655c'), ObjectId('66cdf6beac711620f528655d'), ObjectId('66cdf6beac711620f528655e'), ObjectId('66cdf6beac711620f528655f'), ObjectId('66cdf6beac711620f5286560'), ObjectId('66cdf6beac711620f5286561'), ObjectId('66cdf6beac711620f5286562'), ObjectId('66cdf6beac711620f5286563'), ObjectId('66cdf6beac711620f528 ...

# %%
print(len(posts))
# Out:
# 212

# %%
from groq import Groq
client = Groq(
    # This is the default and can be omitted
    api_key=os.environ.get("GROQ_API_KEY"),
)

# %%
PROMT1 = "You are my social media manager. I will provide you with a post, and you must tell me if it aligns with my interests. Response: You can only reply with either 'yes' or 'no'. Do not include any additional words or sentences. My Interest: I am seeking new opportunities in software development roles, having graduated in 2024 with around 1 year of experience as a full-stack developer (front-end and back-end). I am also interested in roles such as software engineer, web developer, backend engineer, frontend developer, and full-stack engineer. Posts mentioning hiring opportunities, offering referrals, or related to these roles are of the highest interest to me."
PROMT2 = "You are my social media manager , i will give you a post and you have to tell me if that post is good for my interest or not. RESPONSE: you can only respond in one word with either 'yes' or 'no',  MY INTEREST : I am looking for new opportunites in the software engineer, backend engineer, frontend developer,full-stack engineer and related roles,  i passed out in 2024 from a Tier 1 college and i have around 1 year of experience but i can take an opportunity if it is for freshers, I am working as a softwa developer and can work on both frontends and back ends, any post which mentions an hiring opportunity or providing reffral are my of AT MOST INTEREST, Also provide the reason if you are answering with no and think this post is not relevant to me."

# %%
# !pip install groq

def isRelevant( query, prompt = PROMT2, temp = 1):
    if not query :
        return False;
    chat_completion = client.chat.completions.create(messages=[
        {
            'role': 'system',
            'content': prompt if prompt else PROMT2
        },
        {
            'role': 'user',
            'content': "This is this post" + query,
        }],
        model="llama-3.1-70b-versatile",
        temperature=temp,
        top_p=1,
        stream=False,
        stop=None,
    )
    stream  = chat_completion.choices[0].message.content
    response =""
    isQualified = stream.lower().find("yes") != -1
    print("BOT: ", stream)
    return isQualified;

# %%
fetchStatus= "pending"
pending_posts = list(posts_collection.find({"status": fetchStatus}))
print(len(pending_posts))
# Out:
# 212

# %%
shouldSave = input('Do you want to save') 
if shouldSave == "yes" :
    print("saving the posts")
for post in pending_posts:
    isQualified = isRelevant(post["feed_text"], None )
    # isQualified = isRelevant(post["feed_text"]) if not isQualified else None
    if isQualified :
        post["status"] = "qualified"
        print(post["feed_text"]) if fetchStatus == "unqualified" else None;
    else :
        post["status"] = "unqualified"
        print(post["feed_text"]) if fetchStatus == "qualified" else None;
    if shouldSave == "yes" :
        posts_collection.replace_one({"_id": post["_id"]}, post)
# Out:
# Do you want to save yes
# saving the posts
# BOT:  No. (This post appears to be humorous but doesn't contain any job opportunity or information related to your field of interest as a software engineer, backend engineer, frontend developer, or full-stack engineer.)
# BOT:  No.
# Reason: The post is about politics and government, and does not mention any job opportunities or referrals related to software engineering or development.
# BOT:  No.
#
# Reason: The post does not mention any hiring opportunities or referrals for software engineer, backend engineer, frontend developer, or full-stack engineer roles. It appears to be a general article about the Indian startup ecosystem and does not align with your job search interests.
# BOT:  No
# This post seems to be more about learning or an online course to develop skills rather than providing an immediate job opportunity, it might not align with your interests which seems more inclined towards exploring immediate hiring opportunities and utilizing your existing 1-year experience as a software developer.
# ---------------------------------------------------------------------------
# InternalServerError                       Traceback (most recent call last)
# Cell In[36], line 5
#       3     print("saving the posts")
#       4 for post in pending_posts:
# ----> 5     isQualified = isRelevant(post["feed_text"], None )
#       6     # isQualified = isRelevant(post["feed_text"]) if not isQualified else None
#       7     if isQualified :
#
# Cell In[27], line 6, in isRelevant(query, prompt, temp)
#       4 if not query :
#       5     return False;
# ----> 6 chat_completion = client.chat.completions.create(messages=[
#       7     {
#       8         'role': 'system',
#       9         'content': prompt if prompt else PROMT2
#      10     },
#      11     {
#      12         'role': 'user',
#      13         'content': "This is this post" + query,
#      14     }],
#      15     model="llama-3.1-70b-versatile",
#      16     temperature=temp,
#      17     top_p=1,
#      18     stream=False,
#      19     stop=None,
#      20 )
#      21 stream  = chat_completion.choices[0].message.content
#      22 response =""
#
# File ~/.local/lib/python3.10/site-packages/groq/resources/chat/completions.py:289, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     148 def create(
#     149     self,
#     150     *,
#    (...)
#     177     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     178 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     179     """
#     180     Creates a model response for the given chat conversation.
#     181
#    (...)
#     287       timeout: Override the client-level default timeout for this request, in seconds
#     288     """
# --> 289     return self._post(
#     290         "/openai/v1/chat/completions",
#     291         body=maybe_transform(
#     292             {
#     293                 "messages": messages,
#     294                 "model": model,
#     295                 "frequency_penalty": frequency_penalty,
#     296                 "function_call": function_call,
#     297                 "functions": functions,
#     298                 "logit_bias": logit_bias,
#     299                 "logprobs": logprobs,
#     300                 "max_tokens": max_tokens,
#     301                 "n": n,
#     302                 "parallel_tool_calls": parallel_tool_calls,
#     303                 "presence_penalty": presence_penalty,
#     304                 "response_format": response_format,
#     305                 "seed": seed,
#     306                 "stop": stop,
#     307                 "stream": stream,
#     308                 "temperature": temperature,
#     309                 "tool_choice": tool_choice,
#     310                 "tools": tools,
#     311                 "top_logprobs": top_logprobs,
#     312                 "top_p": top_p,
#     313                 "user": user,
#     314             },
#     315             completion_create_params.CompletionCreateParams,
#     316         ),
#     317         options=make_request_options(
#     318             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     319         ),
#     320         cast_to=ChatCompletion,
#     321         stream=stream or False,
#     322         stream_cls=Stream[ChatCompletionChunk],
#     323     )
#
# File ~/.local/lib/python3.10/site-packages/groq/_base_client.py:1225, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1211 def post(
#    1212     self,
#    1213     path: str,
#    (...)
#    1220     stream_cls: type[_StreamT] | None = None,
#    1221 ) -> ResponseT | _StreamT:
#    1222     opts = FinalRequestOptions.construct(
#    1223         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1224     )
# -> 1225     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.local/lib/python3.10/site-packages/groq/_base_client.py:920, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     911 def request(
#     912     self,
#     913     cast_to: Type[ResponseT],
#    (...)
#     918     stream_cls: type[_StreamT] | None = None,
#     919 ) -> ResponseT | _StreamT:
# --> 920     return self._request(
#     921         cast_to=cast_to,
#     922         options=options,
#     923         stream=stream,
#     924         stream_cls=stream_cls,
#     925         remaining_retries=remaining_retries,
#     926     )
#
# File ~/.local/lib/python3.10/site-packages/groq/_base_client.py:1018, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1015         err.response.read()
#    1017     log.debug("Re-raising status error")
# -> 1018     raise self._make_status_error_from_response(err.response) from None
#    1020 return self._process_response(
#    1021     cast_to=cast_to,
#    1022     options=options,
#    (...)
#    1025     stream_cls=stream_cls,
#    1026 )
#
# InternalServerError: Error code: 503 - {'error': {'message': 'Service Unavailable', 'type': 'internal_server_error'}}

# %%
qualified_posts = list(filter(lambda post: post["status"] == "qualified", pending_posts))

# %%
len(qualified_posts)
# Out:
# 0
